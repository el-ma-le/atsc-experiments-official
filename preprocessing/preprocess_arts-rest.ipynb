# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Data Import

# %%
import pandas as pd

# %%
df = pd.read_json(r"/content/drive/My Drive/Masterarbeit/Data/Original/ARTS/rest_test.json")
df = df.transpose()
df.reset_index(inplace=True,drop=True)
df.rename(columns={"sentence":"text"},inplace=True)

# %%
df
# Out:
#                                                    text  ...  to
# 0     Great food, great waitstaff, great atmosphere,...  ...  45
# 1     Great food, great waitstaff, not great atmosph...  ...  49
# 2     Not Great food, not great waitstaff, great atm...  ...  53
# 3     Great food, great waitstaff, great atmosphere,...  ...  45
# 4     Great food, great waitstaff, great atmosphere,...  ...  27
# ...                                                 ...  ...  ..
# 3525  Entrees include classics like lasagna, fettucc...  ...  57
# 3526  Entrees include classics like lasagna, fettucc...  ...  57
# 3527                    The worst though was the taste.  ...  30
# 3528                     The best though was the taste.  ...  29
# 3529  The worst though was the taste, but parking is...  ...  30
#
# [3530 rows x 6 columns]

# %% [markdown]
# # Drop duplicates

# %%
cols_wo_id = df.columns
cols_wo_id = cols_wo_id.drop("id")
df[df.duplicated(cols_wo_id, keep=False)].sort_values("text")
# Out:
#                                                    text  term  ... from  to
# 3256  Not only is the food not authentic, but the st...  food  ...   16  20
# 3266  Not only is the food not authentic, but the st...  food  ...   16  20
# 2103  We been there and we really enjoy the food, wa...  food  ...   38  42
# 2111  We been there and we really enjoy the food, wa...  food  ...   38  42
#
# [4 rows x 6 columns]

# %%
df.drop_duplicates(cols_wo_id, ignore_index=True,inplace=True)

# %%
text_counts = df.text.value_counts()
text_counts[:10]
# Out:
# Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious.                                          13
# Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it not delicious.                                      11
# My Chelsea's impressive and creative menu includes modern, Westernized Japanese dishes such as Foie Gras Unagi Napolean, Jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few.     7
# In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.                            6
# Dishes denoted as "Roy's Classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs.                                                                             6
# " The menu includes pub fare--burgers, steaks and shepherds pie--and even a portabella lasagna for those black sheep known as "vegetarians.                                                                                                                        6
# All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.                                                                                  5
# the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.                                                                                                                        5
# Be sure to try the Smoked Trout...Lamb Chops, Veal Chops, Rabbit, the potato gratin, on and on and on...                                                                                                                                                           5
# The food is great, I love their dumplings, cold sesame noodles, chicken and shrimp dishs.                                                                                                                                                                          5
# Name: text, dtype: int64

# %% [markdown]
# # Descriptive Analysis

# %% [markdown]
# ## Repeating Sentences

# %%
len(df.text.value_counts())
# Out:
# 2784

# %%
df_sent_freq = df.text.value_counts()
df_sent_freq
# Out:
# Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious.                                                13
# Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it not delicious.                                            11
# My Chelsea's impressive and creative menu includes modern, Westernized Japanese dishes such as Foie Gras Unagi Napolean, Jap style hamburger steak, spicy cod roe spaghetti, black cod with miso base, and rack of lamb in black truffle sauce, to name a few.           7
# In addition to great hot dogs, DOTP has wonderful breakfast sandwiches that feature, in addition to great things like tator tots and English muffins, a delicious NJ-based pork product know to us Jersey girls and boys as Taylor ham.                                  6
# Dishes denoted as "Roy's Classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs.                                                                                   6
#                                                                                                                                                                                                                                                                         ..
# Great food, great waitstaff, great atmosphere, but worst of all not GREAT beer!                                                                                                                                                                                          1
# It's traditional, simple italian food, but fish is average, price is not worth and waiters is bad.                                                                                                                                                                       1
# The BEST Chinese food Uptown!                                                                                                                                                                                                                                            1
# Would you ever believe that when you complain about over an hour wait, when they tell you it will be 20-30 minutes, the manager tells the bartender to spill the drinks you just paid for? Although Corinthian cheese ravioli with wild mushrooms is simply great...     1
# The food was mediocre to be kind, the interior is big but not average, the owners are a tag team of unpleasantries, so rude and snotty I actually let out a hearty guffaw whilst dining.                                                                                 1
# Name: text, Length: 2784, dtype: int64

# %%
df[df.text == "Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious."]
# Out:
#                                                   text  ...   to
# 610  Fresh veggies, all sorts of middle eastern spr...  ...   58
# 613  Fresh veggies, all sorts of middle eastern spr...  ...   13
# 614  Fresh veggies, all sorts of middle eastern spr...  ...   82
# 617  Fresh veggies, all sorts of middle eastern spr...  ...  190
# 620  Fresh veggies, all sorts of middle eastern spr...  ...  105
# 625  Fresh veggies, all sorts of middle eastern spr...  ...  120
# 628  Fresh veggies, all sorts of middle eastern spr...  ...  140
# 631  Fresh veggies, all sorts of middle eastern spr...  ...   70
# 634  Fresh veggies, all sorts of middle eastern spr...  ...   50
# 637  Fresh veggies, all sorts of middle eastern spr...  ...  153
# 640  Fresh veggies, all sorts of middle eastern spr...  ...   76
# 643  Fresh veggies, all sorts of middle eastern spr...  ...  169
# 646  Fresh veggies, all sorts of middle eastern spr...  ...   88
#
# [13 rows x 6 columns]

# %% [markdown]
# ## Sentiment Frequency

# %%
df.polarity.value_counts()
# Out:
# positive    1952
# negative    1103
# neutral      473
# Name: polarity, dtype: int64

# %%
sum(df.polarity.value_counts())
# Out:
# 3528

# %% [markdown]
# ## Sentiments of repeating sentences

# %%
df_s = pd.DataFrame(df_sent_freq)
df_s.reset_index(inplace=True)
df_s = df_s.rename(columns={"index":"sentence", "text": "freq"})
df_s
# Out:
#                                                sentence  freq
# 0     Fresh veggies, all sorts of middle eastern spr...    13
# 1     Fresh veggies, all sorts of middle eastern spr...    11
# 2     My Chelsea's impressive and creative menu incl...     7
# 3     In addition to great hot dogs, DOTP has wonder...     6
# 4     Dishes denoted as "Roy's Classics" (marked on ...     6
# ...                                                 ...   ...
# 2779  Great food, great waitstaff, great atmosphere,...     1
# 2780  It's traditional, simple italian food, but fis...     1
# 2781                      The BEST Chinese food Uptown!     1
# 2782  Would you ever believe that when you complain ...     1
# 2783  The food was mediocre to be kind, the interior...     1
#
# [2784 rows x 2 columns]

# %%
df_s.freq.value_counts()
# Out:
# 1     2289
# 2      348
# 3       85
# 4       41
# 5       15
# 6        3
# 13       1
# 11       1
# 7        1
# Name: freq, dtype: int64

# %%
sum(df_s.freq.value_counts())
# Out:
# 2784

# %% [markdown]
# ## Sentences with at least two aspects

# %%
df_min2asp = df_s[df_s.freq > 1]
df_min2asp
# Out:
#                                               sentence  freq
# 0    Fresh veggies, all sorts of middle eastern spr...    13
# 1    Fresh veggies, all sorts of middle eastern spr...    11
# 2    My Chelsea's impressive and creative menu incl...     7
# 3    In addition to great hot dogs, DOTP has wonder...     6
# 4    Dishes denoted as "Roy's Classics" (marked on ...     6
# ..                                                 ...   ...
# 490          The sushi is reasonably priced and fresh.     2
# 491  With all the mundane or mediocre places on 8th...     2
# 492  Appetizer are excellent here; you can make a n...     2
# 493  The service is always great, and the owner wal...     2
# 494  I was on jury duty, rode my bike up Centre Str...     2
#
# [495 rows x 2 columns]

# %% [markdown]
# Subset with at different sentiments.

# %%
diff_sents = 0
for sent in df_min2asp.sentence:
    if len(df[df.text == sent].polarity.value_counts()) > 1:
        diff_sents += 1
diff_sents
# Out:
# 206

# %% [markdown]
# # Check for wrong positions

# %%
mistakes = []
for ii in range(len(df)):
    actual_term = df.term[ii]
    pos_term = df.text[ii][df.loc[ii,"from"]:df.to[ii]]
    if actual_term != pos_term:
        mistakes += [ii]
        print(actual_term, pos_term)
mistakes
# Out:
# pizza  pizz
# delivary delivery
# soup and sandwich meal sandwich meal
# [282, 670, 1611]

# %%
df.loc[282,"to"] += 1
df.loc[282,"from"] += 1

# %%
df.loc[670,"term"] = "delivery"

# %%
df.loc[1611,"from"] -= 9

# %% [markdown]
# # Check for wrong aspect terms

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
for ii in range(len(df)):
    tokens = nltk.word_tokenize(df.text[ii])
    actual_term = df.term[ii]
    for asp_part in nltk.word_tokenize(actual_term):
        if asp_part not in tokens and asp_part+"-" not in tokens:
            print(ii,":",tokens)
            print(actual_term, asp_part)
# Out:
# 279 : ['My', 'only', 'not', 'complaint', 'might', 'be', 'the', 'fortune', 'cookies-I', "'ve", 'never', 'had', 'a', 'cookie', 'predict', 'bad', 'luck', 'for', 'me', 'before', 'I', 'visited', 'Kar', '.']
# fortune cookies cookies
# 737 : ['The', "sangria's-not", 'watered', 'down', '.']
# sangria sangria
# 740 : ['menu-not', 'uneventful', ',', 'big', '.']
# menu menu
# 795 : ['The', 'food', 'was', 'great-sushi', 'was', 'bad', ',', 'but', 'the', 'cooked', 'food', 'amazed', 'us', '.']
# sushi sushi
# 796 : ['The', 'food', 'was', 'not', 'great-sushi', 'was', 'good', ',', 'but', 'the', 'cooked', 'food', 'did', 'not', 'amaze', 'us', '.']
# sushi sushi
# 1133 : ['Had', 'a', 'great', 'experience', 'at', 'Trio', '...', 'staff', 'was', 'pleasant', ';', 'food', 'was', 'tasty', 'but', 'little', 'in', 'portion', 'size-I', 'would', 'highly', 'recommend', 'the', 'portobello/gorgonzola/sausage', 'appetizer', 'and', 'the', 'lobster', 'risotto', '.']
# portion size size
# 1134 : ['Had', 'a', 'great', 'experience', 'at', 'Trio', '...', 'staff', 'was', 'unpleasant', ';', 'food', 'was', 'tasteless', 'but', 'large', 'in', 'portion', 'size-I', 'would', 'highly', 'not', 'recommend', 'the', 'portobello/gorgonzola/sausage', 'appetizer', 'but', 'the', 'lobster', 'risotto', '.']
# portion size size
# 1351 : ['Malted', 'Milk', 'Ball', 'Gelato-have', 'you', 'ever', 'in', 'your', 'life', 'heard', 'of', 'anything', 'so', 'ridiculously', 'not', 'wonderful', '?']
# Malted Milk Ball Gelato Gelato
# 1712 : ['do', "n't", 'get', 'me', 'wrong-sushi', 'was', 'bad', ',', 'just', 'gorgeous', '.']
# sushi sushi
# 1748 : ['And', 'these', 'are', 'not', 'big', ',', 'not', 'wimpy', 'fast', 'food', 'type', 'burgers-these', 'are', 'real', ',', 'full', 'sized', 'patties', '.']
# burgers burgers
# 1749 : ['And', 'these', 'are', 'not', 'small', ',', 'wimpy', 'fast', 'food', 'type', 'burgers-these', 'are', 'insubstantial', ',', 'not', 'full', 'sized', 'patties', '.']
# burgers burgers
# 1957 : ['You', 'must', 'try', 'Odessa', 'stew', 'or', 'Rabbit', 'stew', ';', 'salads-all', 'good', ';', 'and', 'kompot', 'is', 'soo', 'refreshing', 'during', 'the', 'hot', 'summer', 'day', '(', 'they', 'make', 'it', 'the', 'way', 'my', 'mom', 'does', ',', 'reminds', 'me', 'of', 'home', 'a', 'lot', ')', '.']
# salads salads
# 1960 : ['You', 'must', 'try', 'Odessa', 'stew', 'or', 'Rabbit', 'stew', ';', 'salads-all', 'good', ';', 'and', 'kompot', 'is', 'soo', 'refreshing', 'during', 'the', 'hot', 'summer', 'day', '(', 'they', 'make', 'it', 'the', 'way', 'my', 'mom', 'does', ',', 'reminds', 'me', 'of', 'home', 'a', 'lot', ')', ',', 'but', 'sushi', 'is', 'bigger', 'and', 'price', 'is', 'not', 'worth', '.']
# salads salads
# 2333 : ['All', 'are', 'not', 'GREAT-poori', ',', 'naan', ',', 'paratha', 'all', 'FRESH', '.']
# poori poori
# 2334 : ['All', 'are', 'GREAT-poori', ',', 'naan', ',', 'paratha', 'all', 'STALE', '.']
# poori poori
# 3440 : ['Save', 'room', 'for', 'deserts-they', "'re", 'to', 'not', 'die', 'for', '.']
# deserts deserts

# %% [markdown]
# # Convert ID to int

# %%
import numpy as np

# %%
for line in df.index:
    temp = df.id[line].split("_")[0]
    temp = temp.split("#")
    temp2 = temp[2]
    temp = "".join(temp[:2])
    temp = ".".join([temp,temp2])
    temp = temp.replace("#", ".")
    df.id[line] = np.float(temp)

# %% [markdown]
# # Save as CapsNetBERTxml

# %%
import xml.etree.ElementTree as ET

# %%
def xml_maker(df):

    root = ET.Element('sentences')

    for line in df.index:
        name = "sentence"
        entry = ET.SubElement(root, name)
        entry.set("id", str(df["id"][line]))

        text_child = ET.SubElement(entry, "text")
        text_child.text = str(df["text"][line])

        asp_child = ET.SubElement(entry, "aspectTerms")
        asp_subchild = ET.SubElement(asp_child, "aspectTerm")
        asp_subchild.set("from",str(df["from"][line]))
        asp_subchild.set("polarity",str(df["polarity"][line]))
        asp_subchild.set("term",str(df["term"][line]))
        asp_subchild.set("to",str(df["to"][line]))

    return ET.tostring(root)

# %%
xml_data = xml_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/ARTS-REST/test.xml","w") as f:
    f.write(xml_data.decode('utf-8'))

# %% [markdown]
# # Create MGATNxml.seg

# %%
def pol_to_no(sentiment):
  
    if sentiment == "positive":
        pol = 1
    elif sentiment == "negative":
        pol = -1
    elif sentiment == "neutral":
        pol = 0

    return str(pol)

# %%
def xml_seg_maker(df):

    data_lines = []

    for ii in range(len(df)):
        text = df.text[ii].replace(df.term[ii], "$T$")
        pol = pol_to_no(df.polarity[ii])

        data_lines += [text, df.term[ii], pol, str(df.id[ii])]

    return data_lines

# %%
xml_seg_data = xml_seg_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/ARTS-REST/test.xml.seg","w") as f:
    f.write('\n'.join(xml_seg_data))

# %% [markdown]
# # Create BERT+txt

# %%
def sent_conv(sentiment):

    if sentiment == "positive":
        return "POS"
    elif sentiment == "negative":
        return "NEG"
    elif sentiment == "neutral":
        return "NEU"

# %%
from more_itertools import locate

# %%
def txt_maker(df):    
    
    sent_freq = df.text.value_counts()
    data_lines = []

    for text,freq in sent_freq.items():
        
        tokens = nltk.word_tokenize(text)

        # correct tokens
        for no,tok in enumerate(tokens):
            if tok[-1:] == "-" and len(tok)>2:
                tokens[no] = tok[:-1]
            if tok[:1] == "'" and len(tok)>3:
                tokens[no] = tok[1:]
            if tok in ["'","(",")"]:
                tokens.remove(tok)

        # find corresponding lines in df
        text_lines = list(locate(list(df.text), lambda a: a == text))
        assert len(text_lines) == freq

        # create aspect-polarity dict
        asp_sent_dict = {}
        max_asp_len = 0
        for line in text_lines:
            aspect = df.loc[line,"term"]
            if aspect != None:
                asp_sent_dict[aspect] = sent_conv(df.loc[line,"polarity"])
                if len(aspect.split()) > max_asp_len:
                    max_asp_len = len(aspect.split())

        label = ""
        # check for one-word-aspects
        for tok in tokens:
            if tok in asp_sent_dict.keys():
                label += tok + "=T-" + asp_sent_dict[tok] + " "
            else:
                label += tok + "=O "
        label = label[:-1]

        # check for multi-word-aspects
        for ii in range(2,max_asp_len+1):
            for no,tok in enumerate(tokens):
                new_tok = " ".join(tokens[no:no+ii])
                if new_tok in asp_sent_dict.keys():
                    new_pol = asp_sent_dict[new_tok]
                    old_label = " ".join([tokens[no+xx]+"=O" for xx in range(ii) if no+xx < len(tokens)])
                    new_label = " ".join([tokens[no+xx]+"=T-"+new_pol for xx in range(ii) if no+xx < len(tokens)])
                    label = label.replace(old_label, new_label)

        # get ids
        id = []
        for line in text_lines:
            id += [df.loc[line, "id"]]

        assert(len(set(id)) == 1)

        data_lines += [text+"####"+label+"####"+str(id[0])]

    return data_lines

# %%
txt_data = txt_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/ARTS-REST/test.txt","w") as f:
    f.write('\n'.join(txt_data))

# %% [markdown]
# # Create RGATjson

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading https://files.pythonhosted.org/packages/50/ae/a70a58ce6b4e2daad538688806ee0f238dbe601954582a74ea57cde6c532/stanza-1.2-py3-none-any.whl (282kB)
#      |████████████████████████████████| 286kB 22.3MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.8.1+cu101)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (57.0.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Installing collected packages: stanza
# Successfully installed stanza-1.2

# %%
import stanza
from more_itertools import locate
import json

# %%
stanza.download('en')
nlp = stanza.Pipeline('en', processors='tokenize,pos,lemma,depparse')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 23.6MB/s]
# 2021-06-07 09:41:49 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|██████████| 411M/411M [01:14<00:00, 5.51MB/s]
# 2021-06-07 09:43:11 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-06-07 09:43:11 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# | depparse  | combined |
# ========================
#
# 2021-06-07 09:43:11 INFO: Use device: cpu
# 2021-06-07 09:43:11 INFO: Loading: tokenize
# 2021-06-07 09:43:11 INFO: Loading: pos
# 2021-06-07 09:43:11 INFO: Loading: lemma
# 2021-06-07 09:43:12 INFO: Loading: depparse
# 2021-06-07 09:43:12 INFO: Done loading processors!

# %% [markdown]
# ## in case of creating for the first time

# %%
'''
def json_make_pos(df):

    manual_pos = {}
    sent_freq = df.text.value_counts()

    for text,freq in sent_freq.items():
        
        new_dict = {}
        tokens = [token.text for sentence in nlp(text).sentences for token in sentence.tokens]
        
        new_dict["aspects"] = []
        text_lines = list(locate(list(df.text), lambda a: a == text))

        for line in text_lines:
            asp_dict = {}   
            term = df.loc[line,"term"]

            if term != None:
                # construct aspect position on token level
                asp_toks = [token.text for sentence in nlp(term).sentences for token in sentence.tokens]
                asp_ind = [list(locate(tokens, lambda a: a == tok)) for tok in asp_toks]

                # for aspects appearing only once in text, take the correct position
                # otherwise set to None
                if len(asp_ind[0]) == 1:
                    from_index = asp_ind[0][0]
                else:
                    from_index = None
                if len(asp_ind[-1]) == 1:
                    to_index = asp_ind[-1][0] 
                else: 
                    to_index = None

                # if both start and end pos are unknown, 
                # e.g. for single-word aspects, 
                # take character positions for help
                if from_index == None and to_index == None and len(asp_ind[0]) != 0:
                    print(line, ": ", text)
                    print("original term: ",term)
                    all_char_from = [i for i in range(len(text)) if text.startswith(asp_toks[0], i)]
                    print("all start chars: ",all_char_from)
                    corr_char_from = int(df.loc[line, "from"])
                    print("correct start char: ",corr_char_from)
                    print("text beginning at correct start char: ", text[corr_char_from:])
                    print("tokens: ",tokens)
                    print("original asp tokens: ", asp_toks)
                    print("original asp indices: ",asp_ind)
                    if corr_char_from == max(all_char_from):
                        from_index = asp_ind[0][-1]
                    elif corr_char_from == min(all_char_from):
                        from_index = asp_ind[0][0]

                # in case of missing start/end positions,
                # try to find "to"/"from" using aspect token number as distance
                if from_index == None and to_index != None:
                    from_index = to_index - len(asp_toks) +1
                if to_index == None and from_index != None:
                    to_index = from_index + len(asp_toks) -1

                # correct tokenization errors in aspect term tokenization
                if from_index == None or to_index == None or asp_toks != tokens[from_index:to_index+1]:

                    print("Tokenization Error in line ",line,"!")
                    for pos, tok in enumerate(tokens):
                        print(pos, tok)
                    print("aspect term: ", term)
                    print("original asp tokens: ", asp_toks)

                    from_index = int(input("start position?"))
                    to_index = int(input("end position?"))

                    # add manually stated positions to dict for reproducibility
                    manual_pos[text] = {}
                    manual_pos[text][term] = {}
                    manual_pos[text][term]["from"] = from_index
                    manual_pos[text][term]["to"] = to_index
                    print(manual_pos)

                    print("Final aspect tokens: ", tokens[from_index:to_index+1])

                asp_dict["from"] = from_index
                asp_dict["to"] = to_index + 1

    with open("/content/drive/My Drive/Masterarbeit/Data/preprocessing/aspect_positions/arts_rest.json","w") as f:
        json.dump(manual_pos, f)

json_make_pos(df)
'''
# Out:
# 610 :  Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious.
# original term:  cheese
# all start chars:  [52, 155]
# correct start char:  52
# text beginning at correct start char:  cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious.
# tokens:  ['Fresh', 'veggies', ',', 'all', 'sorts', 'of', 'middle', 'eastern', 'spreads', ',', 'cheese', 'and', 'falafel', ',', 'soup', ',', 'fish', ',', 'rice', ',', 'root', 'vegetables', ',', 'a', 'rice', 'medley', ',', 'some', 'spinach', 'thing', ',', 'lamb', 'kebabs', ',', 'cheese', 'baclava', '...', 'soooo', 'much', 'fooood', ',', 'and', 'all', 'of', 'it', 'delicious', '.']
# original asp tokens:  ['cheese']
# original asp indices:  [[10, 34]]
# 646 :  Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious.
# original term:  rice
# all start chars:  [84, 109]
# correct start char:  84
# text beginning at correct start char:  rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious.
# tokens:  ['Fresh', 'veggies', ',', 'all', 'sorts', 'of', 'middle', 'eastern', 'spreads', ',', 'cheese', 'and', 'falafel', ',', 'soup', ',', 'fish', ',', 'rice', ',', 'root', 'vegetables', ',', 'a', 'rice', 'medley', ',', 'some', 'spinach', 'thing', ',', 'lamb', 'kebabs', ',', 'cheese', 'baclava', '...', 'soooo', 'much', 'fooood', ',', 'and', 'all', 'of', 'it', 'delicious', '.']
# original asp tokens:  ['rice']
# original asp indices:  [[18, 24]]
# 611 :  Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it not delicious.
# original term:  cheese
# all start chars:  [52, 155]
# correct start char:  52
# text beginning at correct start char:  cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it not delicious.
# tokens:  ['Fresh', 'veggies', ',', 'all', 'sorts', 'of', 'middle', 'eastern', 'spreads', ',', 'cheese', 'and', 'falafel', ',', 'soup', ',', 'fish', ',', 'rice', ',', 'root', 'vegetables', ',', 'a', 'rice', 'medley', ',', 'some', 'spinach', 'thing', ',', 'lamb', 'kebabs', ',', 'cheese', 'baclava', '...', 'soooo', 'much', 'fooood', ',', 'and', 'all', 'of', 'it', 'not', 'delicious', '.']
# original asp tokens:  ['cheese']
# original asp indices:  [[10, 34]]
# 647 :  Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it not delicious.
# original term:  rice
# all start chars:  [84, 109]
# correct start char:  84
# text beginning at correct start char:  rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it not delicious.
# tokens:  ['Fresh', 'veggies', ',', 'all', 'sorts', 'of', 'middle', 'eastern', 'spreads', ',', 'cheese', 'and', 'falafel', ',', 'soup', ',', 'fish', ',', 'rice', ',', 'root', 'vegetables', ',', 'a', 'rice', 'medley', ',', 'some', 'spinach', 'thing', ',', 'lamb', 'kebabs', ',', 'cheese', 'baclava', '...', 'soooo', 'much', 'fooood', ',', 'and', 'all', 'of', 'it', 'not', 'delicious', '.']
# original asp tokens:  ['rice']
# original asp indices:  [[18, 24]]
# 2715 :  Dishes denoted as "Roy's Classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs.
# original term:  "Roy's Classics"
# all start chars:  [18, 33]
# correct start char:  18
# text beginning at correct start char:  "Roy's Classics" (marked on the menu with asterisks) are tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs.
# tokens:  ['Dishes', 'denoted', 'as', '"', 'Roy', "'s", 'Classics', '"', '(', 'marked', 'on', 'the', 'menu', 'with', 'asterisks', ')', 'are', 'tried', '-', 'and', '-', 'true', 'recipes', ',', 'such', 'as', 'macadamia-crusted', 'mahi', 'mahi', ',', 'or', 'subtly', 'sweet', 'honey', '-', 'mustard', 'beef', 'short', 'ribs', '.']
# original asp tokens:  ['"', 'Roy', "'s", 'Classics', '"']
# original asp indices:  [[3, 7], [4], [5], [6], [3, 7]]
# 1386 :  The food is not average: breakfast food, soups, salads, sandwiches, etc.
# original term:  food
# all start chars:  [4, 35]
# correct start char:  4
# text beginning at correct start char:  food is not average: breakfast food, soups, salads, sandwiches, etc.
# tokens:  ['The', 'food', 'is', 'not', 'average', ':', 'breakfast', 'food', ',', 'soups', ',', 'salads', ',', 'sandwiches', ',', 'etc', '.']
# original asp tokens:  ['food']
# original asp indices:  [[1, 7]]
# 1385 :  The food is average: breakfast food, soups, salads, sandwiches, etc.
# original term:  food
# all start chars:  [4, 31]
# correct start char:  4
# text beginning at correct start char:  food is average: breakfast food, soups, salads, sandwiches, etc.
# tokens:  ['The', 'food', 'is', 'average', ':', 'breakfast', 'food', ',', 'soups', ',', 'salads', ',', 'sandwiches', ',', 'etc', '.']
# original asp tokens:  ['food']
# original asp indices:  [[1, 6]]
# Tokenization Error in line  3349 !
# 0 All-time
# 1 favorites
# 2 include
# 3 the
# 4 Big
# 5 Mac
# 6 ,
# 7 Chicken
# 8 McNuggets
# 9 ,
# 10 Filet
# 11 -O
# 12 -
# 13 Fish
# 14 sandwich
# 15 and
# 16 McDonald
# 17 's
# 18 famous
# 19 french
# 20 fries
# 21 ;
# 22 lighter
# 23 options
# 24 like
# 25 entree-sized
# 26 salads
# 27 are
# 28 also
# 29 available
# 30 .
# aspect term:  Filet-O-Fish sandwich
# original asp tokens:  ['Filet-O', '-', 'Fish', 'sandwich']
# start position?10
# end position?14
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}}
# Final aspect tokens:  ['Filet', '-O', '-', 'Fish', 'sandwich']
# Tokenization Error in line  2743 !
# 0 the
# 1 dinner
# 2 menu
# 3 offers
# 4 a
# 5 variety
# 6 of
# 7 great
# 8 entrees
# 9 ,
# 10 including
# 11 fresh
# 12 seafood
# 13 and
# 14 huge
# 15 steaks
# 16 ,
# 17 there
# 18 's
# 19 also
# 20 a
# 21 couple
# 22 of
# 23 non-
# 24 meat
# 25 alternatives
# 26 .
# aspect term:  non-meat alternatives
# original asp tokens:  ['non-meat', 'alternatives']
# start position?23
# end position?25
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}}
# Final aspect tokens:  ['non-', 'meat', 'alternatives']
# Tokenization Error in line  1124 !
# 0 Had
# 1 a
# 2 great
# 3 experience
# 4 at
# 5 Trio
# 6 ...
# 7 staff
# 8 was
# 9 pleasant
# 10 ;
# 11 food
# 12 was
# 13 tasty
# 14 and
# 15 large
# 16 in
# 17 portion
# 18 size
# 19 -
# 20 I
# 21 would
# 22 highly
# 23 recommend
# 24 the
# 25 portobello
# 26 /
# 27 gorgonzola
# 28 /
# 29 sausage
# 30 appetizer
# 31 and
# 32 the
# 33 lobster
# 34 risotto
# 35 .
# aspect term:  portobello/gorgonzola/sausage appetizer
# original asp tokens:  ['portobello/gorgonzola', '/', 'sausage', 'appetizer']
# start position?25
# end position?30
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}}
# Final aspect tokens:  ['portobello', '/', 'gorgonzola', '/', 'sausage', 'appetizer']
# Tokenization Error in line  3350 !
# 0 All-time
# 1 not
# 2 favorites
# 3 include
# 4 the
# 5 Big
# 6 Mac
# 7 ,
# 8 Chicken
# 9 McNuggets
# 10 ,
# 11 Filet
# 12 -O
# 13 -
# 14 Fish
# 15 sandwich
# 16 and
# 17 McDonald
# 18 's
# 19 famous
# 20 french
# 21 fries
# 22 ;
# 23 lighter
# 24 options
# 25 like
# 26 entree-sized
# 27 salads
# 28 are
# 29 also
# 30 available
# 31 .
# aspect term:  Filet-O-Fish sandwich
# original asp tokens:  ['Filet-O', '-', 'Fish', 'sandwich']
# start position?11
# end position?15
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}}
# Final aspect tokens:  ['Filet', '-O', '-', 'Fish', 'sandwich']
# 2716 :  Dishes denoted as " Roy's Classics " (marked on the menu with asterisks) are not tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs.
# original term:  " Roy's Classics "
# all start chars:  [18, 35]
# correct start char:  18
# text beginning at correct start char:  " Roy's Classics " (marked on the menu with asterisks) are not tried-and-true recipes, such as macadamia-crusted mahi mahi, or subtly sweet honey-mustard beef short ribs.
# tokens:  ['Dishes', 'denoted', 'as', '"', 'Roy', "'s", 'Classics', '"', '(', 'marked', 'on', 'the', 'menu', 'with', 'asterisks', ')', 'are', 'not', 'tried', '-', 'and', '-', 'true', 'recipes', ',', 'such', 'as', 'macadamia-crusted', 'mahi', 'mahi', ',', 'or', 'subtly', 'sweet', 'honey', '-', 'mustard', 'beef', 'short', 'ribs', '.']
# original asp tokens:  ['"', 'Roy', "'s", 'Classics', '"']
# original asp indices:  [[3, 7], [4], [5], [6], [3, 7]]
# 3254 :  Not only is the food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine.
# original term:  food
# all start chars:  [16, 150]
# correct start char:  150
# text beginning at correct start char:  food and wine.
# tokens:  ['Not', 'only', 'is', 'the', 'food', 'authentic', ',', 'but', 'the', 'staff', 'here', 'are', 'practically', 'off', '-', 'the-boat', ',', 'they', 'are', 'young', 'and', 'hip', 'and', 'know', 'what', 'they', 'are', 'doing', 'when', 'it', 'comes', 'to', 'food', 'and', 'wine', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 32]]
# 3264 :  Not only is the food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine.
# original term:  food
# all start chars:  [16, 150]
# correct start char:  16
# text beginning at correct start char:  food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine.
# tokens:  ['Not', 'only', 'is', 'the', 'food', 'authentic', ',', 'but', 'the', 'staff', 'here', 'are', 'practically', 'off', '-', 'the-boat', ',', 'they', 'are', 'young', 'and', 'hip', 'and', 'know', 'what', 'they', 'are', 'doing', 'when', 'it', 'comes', 'to', 'food', 'and', 'wine', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 32]]
# Tokenization Error in line  2476 !
# 0 but
# 1 ,
# 2 the
# 3 filet
# 4 mignon
# 5 was
# 6 not
# 7 very
# 8 good
# 9 at
# 10 all
# 11 cocktail
# 12 hour
# 13 includes
# 14 free
# 15 appetizers
# 16 (
# 17 nice
# 18 non-
# 19 sushi
# 20 selection
# 21 )
# 22 .
# aspect term:  non-sushi selection
# original asp tokens:  ['non-sushi', 'selection']
# start position?18
# end position?20
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}}
# Final aspect tokens:  ['non-', 'sushi', 'selection']
# 2624 :  The unfortunate lady next to us thought she had ordered a salad (including asking for salad dressing) and was instead given a quesedilla.
# original term:  salad
# all start chars:  [58, 86]
# correct start char:  58
# text beginning at correct start char:  salad (including asking for salad dressing) and was instead given a quesedilla.
# tokens:  ['The', 'unfortunate', 'lady', 'next', 'to', 'us', 'thought', 'she', 'had', 'ordered', 'a', 'salad', '(', 'including', 'asking', 'for', 'salad', 'dressing', ')', 'and', 'was', 'instead', 'given', 'a', 'quesedilla', '.']
# original asp tokens:  ['salad']
# original asp indices:  [[11, 16]]
# 2101 :  We been there and we really enjoy the food, was areally great food, and the service was really good.
# original term:  food
# all start chars:  [38, 62]
# correct start char:  62
# text beginning at correct start char:  food, and the service was really good.
# tokens:  ['We', 'been', 'there', 'and', 'we', 'really', 'enjoy', 'the', 'food', ',', 'was', 'areally', 'great', 'food', ',', 'and', 'the', 'service', 'was', 'really', 'good', '.']
# original asp tokens:  ['food']
# original asp indices:  [[8, 13]]
# 2109 :  We been there and we really enjoy the food, was areally great food, and the service was really good.
# original term:  food
# all start chars:  [38, 62]
# correct start char:  38
# text beginning at correct start char:  food, was areally great food, and the service was really good.
# tokens:  ['We', 'been', 'there', 'and', 'we', 'really', 'enjoy', 'the', 'food', ',', 'was', 'areally', 'great', 'food', ',', 'and', 'the', 'service', 'was', 'really', 'good', '.']
# original asp tokens:  ['food']
# original asp indices:  [[8, 13]]
# Tokenization Error in line  2248 !
# 0 It
# 1 's
# 2 about
# 3 $
# 4 7
# 5 for
# 6 lunch
# 7 and
# 8 they
# 9 have
# 10 take
# 11 -
# 12 out
# 13 or
# 14 dine
# 15 -
# 16 in
# 17 .
# aspect term:  take-out
# original asp tokens:  ['take-out']
# start position?10
# end position?12
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}}
# Final aspect tokens:  ['take', '-', 'out']
# Tokenization Error in line  365 !
# 0 Innovations
# 1 are
# 2 just
# 3 as
# 4 assured
# 5 ,
# 6 from
# 7 the
# 8 simple
# 9 Carinthia
# 10 cheese
# 11 ravioli
# 12 with
# 13 wild
# 14 mushrooms
# 15 to
# 16 the
# 17 caviar-
# 18 topped
# 19 sturgeon
# 20 ,
# 21 beautifully
# 22 matched
# 23 with
# 24 a
# 25 bright
# 26 green
# 27 spinach
# 28 -
# 29 vodka
# 30 sauce
# 31 .
# aspect term:  caviar-topped sturgeon
# original asp tokens:  ['caviar', '-', 'topped', 'sturgeon']
# start position?17
# end position?19
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}}
# Final aspect tokens:  ['caviar-', 'topped', 'sturgeon']
# 798 :  The food was great - sushi was good, but the cooked food amazed us.
# original term:  food
# all start chars:  [4, 52]
# correct start char:  4
# text beginning at correct start char:  food was great - sushi was good, but the cooked food amazed us.
# tokens:  ['The', 'food', 'was', 'great', '-', 'sushi', 'was', 'good', ',', 'but', 'the', 'cooked', 'food', 'amazed', 'us', '.']
# original asp tokens:  ['food']
# original asp indices:  [[1, 12]]
# Tokenization Error in line  3351 !
# 0 All-time
# 1 favorites
# 2 include
# 3 the
# 4 Big
# 5 Mac
# 6 ,
# 7 Chicken
# 8 McNuggets
# 9 ,
# 10 Filet
# 11 -O
# 12 -
# 13 Fish
# 14 sandwich
# 15 and
# 16 McDonald
# 17 's
# 18 famous
# 19 french
# 20 fries
# 21 ;
# 22 decidedly
# 23 lighter
# 24 options
# 25 like
# 26 entree-sized
# 27 salads
# 28 are
# 29 also
# 30 available
# 31 .
# aspect term:  Filet-O-Fish sandwich
# original asp tokens:  ['Filet-O', '-', 'Fish', 'sandwich']
# start position?11
# end position?14
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}}
# Final aspect tokens:  ['-O', '-', 'Fish', 'sandwich']
# Tokenization Error in line  1125 !
# 0 Had
# 1 a
# 2 great
# 3 experience
# 4 at
# 5 Trio
# 6 ...
# 7 staff
# 8 was
# 9 pleasant
# 10 ;
# 11 food
# 12 was
# 13 tasty
# 14 and
# 15 large
# 16 in
# 17 portion
# 18 size
# 19 -
# 20 I
# 21 would
# 22 highly
# 23 not
# 24 recommend
# 25 the
# 26 portobello
# 27 /
# 28 gorgonzola
# 29 /
# 30 sausage
# 31 appetizer
# 32 and
# 33 the
# 34 lobster
# 35 risotto
# 36 .
# aspect term:  portobello/gorgonzola/sausage appetizer
# original asp tokens:  ['portobello/gorgonzola', '/', 'sausage', 'appetizer']
# start position?26
# end position?31
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}}
# Final aspect tokens:  ['portobello', '/', 'gorgonzola', '/', 'sausage', 'appetizer']
# Tokenization Error in line  375 !
# 0 Menus
# 1 feature
# 2 seasonal
# 3 picks
# 4 ,
# 5 like
# 6 sweet
# 7 corn
# 8 -
# 9 foie
# 10 gras
# 11 brulee
# 12 .
# aspect term:  sweet corn-foie gras brulee
# original asp tokens:  ['sweet', 'corn-foie', 'gras', 'brulee']
# start position?6
# end position?11
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}}
# Final aspect tokens:  ['sweet', 'corn', '-', 'foie', 'gras', 'brulee']
# 3265 :  Not only is the food authentic, but the staff here are practically not off-the-boat, they are young but hip and old what not hip are doing when it comes to food and wine.
# original term:  food
# all start chars:  [16, 156]
# correct start char:  16
# text beginning at correct start char:  food authentic, but the staff here are practically not off-the-boat, they are young but hip and old what not hip are doing when it comes to food and wine.
# tokens:  ['Not', 'only', 'is', 'the', 'food', 'authentic', ',', 'but', 'the', 'staff', 'here', 'are', 'practically', 'not', 'off', '-', 'the-boat', ',', 'they', 'are', 'young', 'but', 'hip', 'and', 'old', 'what', 'not', 'hip', 'are', 'doing', 'when', 'it', 'comes', 'to', 'food', 'and', 'wine', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 34]]
# 1796 :  The place is clean, but if you dislike soul food, then this is the place to be!
# original term:  place
# all start chars:  [4, 67]
# correct start char:  4
# text beginning at correct start char:  place is clean, but if you dislike soul food, then this is the place to be!
# tokens:  ['The', 'place', 'is', 'clean', ',', 'but', 'if', 'you', 'dislike', 'soul', 'food', ',', 'then', 'this', 'is', 'the', 'place', 'to', 'be', '!']
# original asp tokens:  ['place']
# original asp indices:  [[1, 16]]
# 1795 :  The place is dirty, but if you like soul food, then this is the place to be!
# original term:  place
# all start chars:  [4, 64]
# correct start char:  4
# text beginning at correct start char:  place is dirty, but if you like soul food, then this is the place to be!
# tokens:  ['The', 'place', 'is', 'dirty', ',', 'but', 'if', 'you', 'like', 'soul', 'food', ',', 'then', 'this', 'is', 'the', 'place', 'to', 'be', '!']
# original asp tokens:  ['place']
# original asp indices:  [[1, 16]]
# 61 :  You can eat gourmet food at a fast food price.
# original term:  food
# all start chars:  [20, 35]
# correct start char:  20
# text beginning at correct start char:  food at a fast food price.
# tokens:  ['You', 'can', 'eat', 'gourmet', 'food', 'at', 'a', 'fast', 'food', 'price', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 8]]
# 2103 :  We been there and we really enjoy the food, was areally great food, but the service was really bad.
# original term:  food
# all start chars:  [38, 62]
# correct start char:  38
# text beginning at correct start char:  food, was areally great food, but the service was really bad.
# tokens:  ['We', 'been', 'there', 'and', 'we', 'really', 'enjoy', 'the', 'food', ',', 'was', 'areally', 'great', 'food', ',', 'but', 'the', 'service', 'was', 'really', 'bad', '.']
# original asp tokens:  ['food']
# original asp indices:  [[8, 13]]
# 2023 :  Good cake BUT: it was not the best cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees.
# original term:  cake
# all start chars:  [5, 35]
# correct start char:  35
# text beginning at correct start char:  cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees.
# tokens:  ['Good', 'cake', 'BUT', ':', 'it', 'was', 'not', 'the', 'best', 'cake', "i've", 'ever', 'had', ',', 'and', 'definately', 'not', 'worth', 'standing', 'outside', 'on', 'the', 'sidewalk', 'being', 'herded', 'like', 'cattle', 'by', 'indifferent', 'and', 'overworked', 'employees', '.']
# original asp tokens:  ['cake']
# original asp indices:  [[1, 9]]
# 1794 :  The place is clean, and if you like soul food, then this is the place to be!
# original term:  place
# all start chars:  [4, 64]
# correct start char:  4
# text beginning at correct start char:  place is clean, and if you like soul food, then this is the place to be!
# tokens:  ['The', 'place', 'is', 'clean', ',', 'and', 'if', 'you', 'like', 'soul', 'food', ',', 'then', 'this', 'is', 'the', 'place', 'to', 'be', '!']
# original asp tokens:  ['place']
# original asp indices:  [[1, 16]]
# 994 :  And the food, well the food will keep you coming back.
# original term:  food
# all start chars:  [8, 23]
# correct start char:  23
# text beginning at correct start char:  food will keep you coming back.
# tokens:  ['And', 'the', 'food', ',', 'well', 'the', 'food', 'will', 'keep', 'you', 'coming', 'back', '.']
# original asp tokens:  ['food']
# original asp indices:  [[2, 6]]
# 996 :  And the food, well the food will keep you coming back.
# original term:  food
# all start chars:  [8, 23]
# correct start char:  8
# text beginning at correct start char:  food, well the food will keep you coming back.
# tokens:  ['And', 'the', 'food', ',', 'well', 'the', 'food', 'will', 'keep', 'you', 'coming', 'back', '.']
# original asp tokens:  ['food']
# original asp indices:  [[2, 6]]
# Tokenization Error in line  366 !
# 0 Innovations
# 1 are
# 2 just
# 3 as
# 4 assured
# 5 ,
# 6 from
# 7 the
# 8 simple
# 9 Carinthia
# 10 cheese
# 11 ravioli
# 12 with
# 13 wild
# 14 mushrooms
# 15 to
# 16 the
# 17 caviar-
# 18 topped
# 19 sturgeon
# 20 ,
# 21 beautifully
# 22 matched
# 23 with
# 24 a
# 25 bright
# 26 green
# 27 spinach
# 28 -
# 29 vodka
# 30 sauce
# 31 ,
# 32 but
# 33 lunch
# 34 is
# 35 a
# 36 power
# 37 ,
# 38 price
# 39 is
# 40 not
# 41 worth
# 42 and
# 43 fortune
# 44 cookies
# 45 is
# 46 a
# 47 complaint
# 48 .
# aspect term:  caviar-topped sturgeon
# original asp tokens:  ['caviar', '-', 'topped', 'sturgeon']
# start position?17
# end position?19
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce, but lunch is a power, price is not worth and fortune cookies is a complaint.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}}
# Final aspect tokens:  ['caviar-', 'topped', 'sturgeon']
# 2102 :  We have been there and we really did not enjoy the food, it was really bad food, but the service was really good.
# original term:  food
# all start chars:  [51, 75]
# correct start char:  51
# text beginning at correct start char:  food, it was really bad food, but the service was really good.
# tokens:  ['We', 'have', 'been', 'there', 'and', 'we', 'really', 'did', 'not', 'enjoy', 'the', 'food', ',', 'it', 'was', 'really', 'bad', 'food', ',', 'but', 'the', 'service', 'was', 'really', 'good', '.']
# original asp tokens:  ['food']
# original asp indices:  [[11, 17]]
# 3255 :  Not only is the food not authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine.
# original term:  food
# all start chars:  [16, 154]
# correct start char:  16
# text beginning at correct start char:  food not authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine.
# tokens:  ['Not', 'only', 'is', 'the', 'food', 'not', 'authentic', ',', 'but', 'the', 'staff', 'here', 'are', 'practically', 'off', '-', 'the-boat', ',', 'they', 'are', 'young', 'and', 'hip', 'and', 'know', 'what', 'they', 'are', 'doing', 'when', 'it', 'comes', 'to', 'food', 'and', 'wine', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 33]]
# 1177 :  The food really isn't very good and the service is terrible, but Indian food is serious, hot dogs is best and service is good.
# original term:  food
# all start chars:  [4, 72]
# correct start char:  4
# text beginning at correct start char:  food really isn't very good and the service is terrible, but Indian food is serious, hot dogs is best and service is good.
# tokens:  ['The', 'food', 'really', 'is', "n't", 'very', 'good', 'and', 'the', 'service', 'is', 'terrible', ',', 'but', 'Indian', 'food', 'is', 'serious', ',', 'hot', 'dogs', 'is', 'best', 'and', 'service', 'is', 'good', '.']
# original asp tokens:  ['food']
# original asp indices:  [[1, 15]]
# Tokenization Error in line  1127 !
# 0 Had
# 1 a
# 2 great
# 3 experience
# 4 at
# 5 Trio
# 6 ...
# 7 staff
# 8 was
# 9 pleasant
# 10 ;
# 11 food
# 12 was
# 13 tasty
# 14 and
# 15 large
# 16 in
# 17 portion
# 18 size
# 19 -
# 20 I
# 21 would
# 22 highly
# 23 recommend
# 24 the
# 25 portobello
# 26 /
# 27 gorgonzola
# 28 /
# 29 sausage
# 30 appetizer
# 31 and
# 32 the
# 33 lobster
# 34 risotto
# 35 ,
# 36 but
# 37 hostess
# 38 is
# 39 rude
# 40 and
# 41 food
# 42 is
# 43 is
# 44 n't
# 45 very
# 46 good
# 47 .
# aspect term:  portobello/gorgonzola/sausage appetizer
# original asp tokens:  ['portobello/gorgonzola', '/', 'sausage', 'appetizer']
# start position?25
# end position?30
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce, but lunch is a power, price is not worth and fortune cookies is a complaint.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto, but hostess is rude and food is isn't very good.": {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}}
# Final aspect tokens:  ['portobello', '/', 'gorgonzola', '/', 'sausage', 'appetizer']
# Tokenization Error in line  376 !
# 0 Menus
# 1 feature
# 2 seasonal
# 3 picks
# 4 ,
# 5 like
# 6 sweet
# 7 corn
# 8 -
# 9 foie
# 10 gras
# 11 brulee
# 12 ,
# 13 but
# 14 price
# 15 is
# 16 good
# 17 and
# 18 waiters
# 19 is
# 20 bad
# 21 .
# aspect term:  sweet corn-foie gras brulee
# original asp tokens:  ['sweet', 'corn-foie', 'gras', 'brulee']
# start position?6
# end position?11
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce, but lunch is a power, price is not worth and fortune cookies is a complaint.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto, but hostess is rude and food is isn't very good.": {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee, but price is good and waiters is bad.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}}
# Final aspect tokens:  ['sweet', 'corn', '-', 'foie', 'gras', 'brulee']
# 62 :  You can't eat gourmet food at a fast food price.
# original term:  food
# all start chars:  [22, 37]
# correct start char:  22
# text beginning at correct start char:  food at a fast food price.
# tokens:  ['You', 'ca', "n't", 'eat', 'gourmet', 'food', 'at', 'a', 'fast', 'food', 'price', '.']
# original asp tokens:  ['food']
# original asp indices:  [[5, 9]]
# 2760 :  everything is scrumptious, from the excellent service by cute waitresses, to the extremely lush atmosphere, but dinners is a power, space is tasty and bar service is slow.
# original term:  service
# all start chars:  [46, 155]
# correct start char:  46
# text beginning at correct start char:  service by cute waitresses, to the extremely lush atmosphere, but dinners is a power, space is tasty and bar service is slow.
# tokens:  ['everything', 'is', 'scrumptious', ',', 'from', 'the', 'excellent', 'service', 'by', 'cute', 'waitresses', ',', 'to', 'the', 'extremely', 'lush', 'atmosphere', ',', 'but', 'dinners', 'is', 'a', 'power', ',', 'space', 'is', 'tasty', 'and', 'bar', 'service', 'is', 'slow', '.']
# original asp tokens:  ['service']
# original asp indices:  [[7, 29]]
# 3266 :  Not only is the food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine; room is plain.
# original term:  food
# all start chars:  [16, 150]
# correct start char:  16
# text beginning at correct start char:  food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine; room is plain.
# tokens:  ['Not', 'only', 'is', 'the', 'food', 'authentic', ',', 'but', 'the', 'staff', 'here', 'are', 'practically', 'off', '-', 'the-boat', ',', 'they', 'are', 'young', 'and', 'hip', 'and', 'know', 'what', 'they', 'are', 'doing', 'when', 'it', 'comes', 'to', 'food', 'and', 'wine', ';', 'room', 'is', 'plain', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 32]]
# 281 :  It's a basic pizza joint, not much to look at, but the pizza is what I go for.
# original term:  pizza
# all start chars:  [13, 55]
# correct start char:  55
# text beginning at correct start char:  pizza is what I go for.
# tokens:  ['It', "'s", 'a', 'basic', 'pizza', 'joint', ',', 'not', 'much', 'to', 'look', 'at', ',', 'but', 'the', 'pizza', 'is', 'what', 'I', 'go', 'for', '.']
# original asp tokens:  ['pizza']
# original asp indices:  [[4, 15]]
# Tokenization Error in line  2478 !
# 0 but
# 1 ,
# 2 the
# 3 filet
# 4 mignon
# 5 was
# 6 not
# 7 extremely
# 8 not
# 9 very
# 10 good
# 11 at
# 12 all
# 13 cocktail
# 14 hour
# 15 includes
# 16 free
# 17 appetizers
# 18 (
# 19 nice
# 20 non-
# 21 sushi
# 22 selection
# 23 )
# 24 .
# aspect term:  non-sushi selection
# original asp tokens:  ['non-sushi', 'selection']
# start position?20
# end position?22
# ...
# Final aspect tokens:  ['Malted', 'Milk', 'Ball', 'Gelato-have']
# 63 :  You can eat gourmet food at a fast food price, but mole sauce is too sweet, service is rude and wait staff is inconsiderate.
# original term:  food
# all start chars:  [20, 35]
# correct start char:  20
# text beginning at correct start char:  food at a fast food price, but mole sauce is too sweet, service is rude and wait staff is inconsiderate.
# tokens:  ['You', 'can', 'eat', 'gourmet', 'food', 'at', 'a', 'fast', 'food', 'price', ',', 'but', 'mole', 'sauce', 'is', 'too', 'sweet', ',', 'service', 'is', 'rude', 'and', 'wait', 'staff', 'is', 'inconsiderate', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 8]]
# Tokenization Error in line  3352 !
# 0 All-time
# 1 favorites
# 2 include
# 3 the
# 4 Big
# 5 Mac
# 6 ,
# 7 Chicken
# 8 McNuggets
# 9 ,
# 10 Filet
# 11 -O
# 12 -
# 13 Fish
# 14 sandwich
# 15 and
# 16 McDonald
# 17 's
# 18 famous
# 19 french
# 20 fries
# 21 ;
# 22 lighter
# 23 options
# 24 like
# 25 entree-sized
# 26 salads
# 27 are
# 28 also
# 29 available
# 30 ,
# 31 but
# 32 filet
# 33 minor
# 34 is
# 35 not
# 36 very
# 37 good
# 38 .
# aspect term:  Filet-O-Fish sandwich
# original asp tokens:  ['Filet-O', '-', 'Fish', 'sandwich']
# start position?10
# end position?14
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce, but lunch is a power, price is not worth and fortune cookies is a complaint.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto, but hostess is rude and food is isn't very good.": {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee, but price is good and waiters is bad.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'but, the filet mignon was not extremely not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 20, 'to': 22}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nasty non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "if you're looking for authentic hong kong-style food, look no further, but staff is bad.": {'hong kong-style food': {'from': 6, 'to': 10}}, 'Had a great experience at Trio... staff was unpleasant; food was tasteless but small in portion size-I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives, but fennel flavored Italian sausage is heavy, chicken is a love and lamb entree is good.": {'non-meat alternatives': {'from': 23, 'to': 26}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi sel ...
# Final aspect tokens:  ['Filet', '-O', '-', 'Fish', 'sandwich']
# 2467 :  now called nikki sushi, sushi is OK, but appetizers is not expensive, wine list is disappointing and place is good.
# original term:  sushi
# all start chars:  [17, 24]
# correct start char:  24
# text beginning at correct start char:  sushi is OK, but appetizers is not expensive, wine list is disappointing and place is good.
# tokens:  ['now', 'called', 'nikki', 'sushi', ',', 'sushi', 'is', 'OK', ',', 'but', 'appetizers', 'is', 'not', 'expensive', ',', 'wine', 'list', 'is', 'disappointing', 'and', 'place', 'is', 'good', '.']
# original asp tokens:  ['sushi']
# original asp indices:  [[3, 5]]
# 2024 :  Evilness cake BUT: it was not the best cake i've ever had, and definately worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees.
# original term:  cake
# all start chars:  [9, 39]
# correct start char:  9
# text beginning at correct start char:  cake BUT: it was not the best cake i've ever had, and definately worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees.
# tokens:  ['Evilness', 'cake', 'BUT', ':', 'it', 'was', 'not', 'the', 'best', 'cake', "i've", 'ever', 'had', ',', 'and', 'definately', 'worth', 'standing', 'outside', 'on', 'the', 'sidewalk', 'being', 'herded', 'like', 'cattle', 'by', 'indifferent', 'and', 'overworked', 'employees', '.']
# original asp tokens:  ['cake']
# original asp indices:  [[1, 9]]
# Tokenization Error in line  2591 !
# 0 if
# 1 you
# 2 're
# 3 looking
# 4 for
# 5 authentic
# 6 hong
# 7 kong
# 8 -
# 9 style
# 10 food
# 11 ,
# 12 look
# 13 no
# 14 further
# 15 .
# aspect term:  hong kong-style food
# original asp tokens:  ['hong', 'kong', '-style', 'food']
# start position?6
# end position?10
# {"All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 10, 'to': 14}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives.": {'non-meat alternatives': {'from': 23, 'to': 25}}, 'Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "All-time not favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 15}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "It's about $7 for lunch and they have take-out or dine-in.": {'take-out': {'from': 10, 'to': 12}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "All-time favorites include the Big Mac, Chicken McNuggets, Filet-O-Fish sandwich and McDonald's famous french fries; decidedly lighter options like entree-sized salads are also available.": {'Filet-O-Fish sandwich': {'from': 11, 'to': 14}}, 'Had a great experience at Trio... staff was pleasant; food was tasty and large in portion size-I would highly not recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 26, 'to': 31}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'Innovations are just as assured, from the simple Carinthia cheese ravioli with wild mushrooms to the caviar-topped sturgeon, beautifully matched with a bright green spinach-vodka sauce, but lunch is a power, price is not worth and fortune cookies is a complaint.': {'caviar-topped sturgeon': {'from': 17, 'to': 19}}, "Had a great experience at Trio ... staff was pleasant; food was tasty and large in portion size - I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto, but hostess is rude and food is isn't very good.": {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, 'Menus feature seasonal picks, like sweet corn-foie gras brulee, but price is good and waiters is bad.': {'sweet corn-foie gras brulee': {'from': 6, 'to': 11}}, 'but, the filet mignon was not extremely not very good at all cocktail hour includes free appetizers (nice non-sushi selection).': {'non-sushi selection': {'from': 20, 'to': 22}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nasty non-sushi selection).': {'non-sushi selection': {'from': 18, 'to': 20}}, "if you're looking for authentic hong kong-style food, look no further, but staff is bad.": {'hong kong-style food': {'from': 6, 'to': 10}}, 'Had a great experience at Trio... staff was unpleasant; food was tasteless but small in portion size-I would highly recommend the portobello/gorgonzola/sausage appetizer and the lobster risotto.': {'portobello/gorgonzola/sausage appetizer': {'from': 25, 'to': 30}}, "the dinner menu offers a variety of great entrees, including fresh seafood and huge steaks, there's also a couple of non-meat alternatives, but fennel flavored Italian sausage is heavy, chicken is a love and lamb entree is good.": {'non-meat alternatives': {'from': 23, 'to': 26}}, 'but, the filet mignon was not very good at all cocktail hour includes free appetizers (nice non-sushi sel ...
# Final aspect tokens:  ['hong', 'kong', '-', 'style', 'food']
# 648 :  Fresh veggies, all sorts of middle eastern spreads, cheese and falafel, soup, fish, rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious, but fortune cookies is a complaint and wait staff is inconsiderate.
# original term:  rice
# all start chars:  [84, 109]
# correct start char:  84
# text beginning at correct start char:  rice, root vegetables, a rice medley, some spinach thing, lamb kebabs, cheese baclava... soooo much fooood, and all of it delicious, but fortune cookies is a complaint and wait staff is inconsiderate.
# tokens:  ['Fresh', 'veggies', ',', 'all', 'sorts', 'of', 'middle', 'eastern', 'spreads', ',', 'cheese', 'and', 'falafel', ',', 'soup', ',', 'fish', ',', 'rice', ',', 'root', 'vegetables', ',', 'a', 'rice', 'medley', ',', 'some', 'spinach', 'thing', ',', 'lamb', 'kebabs', ',', 'cheese', 'baclava', '...', 'soooo', 'much', 'fooood', ',', 'and', 'all', 'of', 'it', 'delicious', ',', 'but', 'fortune', 'cookies', 'is', 'a', 'complaint', 'and', 'wait', 'staff', 'is', 'inconsiderate', '.']
# original asp tokens:  ['rice']
# original asp indices:  [[18, 24]]
# 3257 :  Not only is the food authentic, but the staff here are practically off-the-boat, they are young and hip and know what they are doing when it comes to food and wine; service is worst.
# original term:  food
# all start chars:  [16, 150]
# correct start char:  150
# text beginning at correct start char:  food and wine; service is worst.
# tokens:  ['Not', 'only', 'is', 'the', 'food', 'authentic', ',', 'but', 'the', 'staff', 'here', 'are', 'practically', 'off', '-', 'the-boat', ',', 'they', 'are', 'young', 'and', 'hip', 'and', 'know', 'what', 'they', 'are', 'doing', 'when', 'it', 'comes', 'to', 'food', 'and', 'wine', ';', 'service', 'is', 'worst', '.']
# original asp tokens:  ['food']
# original asp indices:  [[4, 32]]
# 799 :  The food was not great-sushi was good, but the cooked food amazed us.
# original term:  food
# all start chars:  [4, 54]
# correct start char:  4
# text beginning at correct start char:  food was not great-sushi was good, but the cooked food amazed us.
# tokens:  ['The', 'food', 'was', 'not', 'great', '-', 'sushi', 'was', 'good', ',', 'but', 'the', 'cooked', 'food', 'amazed', 'us', '.']
# original asp tokens:  ['food']
# original asp indices:  [[1, 13]]
# 2025 :  Good cake BUT: it was not the best cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees, but meal is inexpensive.
# original term:  cake
# all start chars:  [5, 35]
# correct start char:  35
# text beginning at correct start char:  cake i've ever had, and definately not worth standing outside on the sidewalk being herded like cattle by indifferent and overworked employees, but meal is inexpensive.
# tokens:  ['Good', 'cake', 'BUT', ':', 'it', 'was', 'not', 'the', 'best', 'cake', "i've", 'ever', 'had', ',', 'and', 'definately', 'not', 'worth', 'standing', 'outside', 'on', 'the', 'sidewalk', 'being', 'herded', 'like', 'cattle', 'by', 'indifferent', 'and', 'overworked', 'employees', ',', 'but', 'meal', 'is', 'inexpensive', '.']
# original asp tokens:  ['cake']
# original asp indices:  [[1, 9]]

# %% [markdown]
# ## in case of reproducing the dataset

# %%
def json_maker(df, manual_pos):
   
    new_data = []
    sent_freq = df.text.value_counts()

    for text,freq in sent_freq.items():
        
        new_dict = {}

        tokens = [token.text for sentence in nlp(text).sentences for token in sentence.tokens]
        new_dict["token"] = tokens

        new_dict["pos"] = [word.xpos for sentence in nlp(text).sentences for word in sentence.words]
        new_dict["head"] = [str(word.head) for sentence in nlp(text).sentences for word in sentence.words]
        new_dict["deprel"] = [word.deprel for sentence in nlp(text).sentences for word in sentence.words]
        
        new_dict["aspects"] = []
        text_lines = list(locate(list(df.text), lambda a: a == text))

        ids = []
        for line in text_lines:
            asp_dict = {}   
            term = df.loc[line,"term"]
            ids += [df.loc[line,"id"]]

            if term != None:
                asp_dict["term"] = term
                asp_dict["polarity"] = df.loc[line,"polarity"]

                # construct aspect position on token level
                asp_toks = [token.text for sentence in nlp(term).sentences for token in sentence.tokens]
                asp_ind = [list(locate(tokens, lambda a: a == tok)) for tok in asp_toks]

                # for aspects appearing only once in text, take the correct position
                # otherwise set to None
                if len(asp_ind[0]) == 1:
                    from_index = asp_ind[0][0]
                else:
                    from_index = None
                if len(asp_ind[-1]) == 1:
                    to_index = asp_ind[-1][0] 
                else: 
                    to_index = None

                # if both start and end pos are unknown, 
                # e.g. for single-word aspects, 
                # take character positions for help
                if from_index == None and to_index == None and len(asp_ind[0]) != 0:

                    all_char_from = [i for i in range(len(text)) if text.startswith(asp_toks[0], i)]
                    corr_char_from = int(df.loc[line, "from"])

                    if corr_char_from == max(all_char_from):
                        from_index = asp_ind[0][-1]
                    elif corr_char_from == min(all_char_from):
                        from_index = asp_ind[0][0]

                # in case of missing start/end positions,
                # try to find "to"/"from" using aspect token number as distance
                if from_index == None and to_index != None:
                    from_index = to_index - len(asp_toks) +1
                if to_index == None and from_index != None:
                    to_index = from_index + len(asp_toks) -1

                # correct tokenization errors in aspect term tokenization
                if from_index == None or to_index == None or asp_toks != tokens[from_index:to_index+1]:
                    if text in manual_pos.keys() and term in manual_pos[text].keys():
                        from_index = manual_pos[text][term]["from"]
                        to_index = manual_pos[text][term]["to"]

                asp_dict["from"] = from_index
                asp_dict["to"] = to_index + 1

            new_dict["aspects"] += [asp_dict]
        
        assert len(set(ids)) == 1
        new_dict["id"] = ids[0]

        new_data += [new_dict]

    return new_data

# %%
pos_obj = open("/content/drive/My Drive/Masterarbeit/Data/preprocessing/aspect_positions/arts_rest.json")
loaded_pos = json.load(pos_obj)

json_data = json_maker(df, loaded_pos)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/ARTS-REST/test.json","w") as f:
    json.dump(json_data, f)

# %% [markdown]
# # Create LCF-ATEPCdat

# %%
def pol_to_no_shifted(sentiment):
  
    if sentiment == "positive":
        pol = 2
    elif sentiment == "negative":
        pol = 0
    elif sentiment == "neutral":
        pol = 1

    return str(pol)

# %%
def dat_maker(df):
    
    data_lines = []
    sent_freq = df.text.value_counts()

    for text,freq in sent_freq.items():

        tokens = nltk.word_tokenize(text)

        # correct tokens
        for no,tok in enumerate(tokens):
            if tok[-1:] == "-" and len(tok)>2:
                tokens[no] = tok[:-1]
            if tok[:1] == "'" and len(tok)>3:
                tokens[no] = tok[1:]
            if tok in ["'","(",")"]:
                tokens.remove(tok)

        text_lines = list(locate(list(df.text), lambda a: a == text))

        # create aspect-polarity dict
        asp_sent_dict = {}
        ids = []
        max_asp_len = 0
        for line in text_lines:
            aspect = df.loc[line,"term"]
            ids += [df.loc[line,"id"]]
            if aspect != None:
                asp_sent_dict[aspect] = pol_to_no_shifted(df.loc[line,"polarity"])
                if len(aspect.split()) > max_asp_len:
                    max_asp_len = len(aspect.split())

        assert len(set(ids)) == 1

        label = ""
        # check for one-word-aspects
        for tok in tokens:
            if tok in asp_sent_dict.keys():
                label += tok + " B-ASP -1\n"
            else:
                label += tok + " O -1\n"

        # check for multi-word-aspects
        for ii in range(2,max_asp_len+1):
            for no,tok in enumerate(tokens):
                new_tok = " ".join(tokens[no:no+ii])
                if new_tok not in tokens and new_tok in asp_sent_dict.keys():
                    label = label.replace(tokens[no]+" O -1",tokens[no]+" B-ASP -1")
                    for xx in range(1,ii):
                        label = label.replace(tokens[no+xx]+" O -1",tokens[no+xx]+" I-ASP -1")

        # create duplicates of review in case of more than one aspect
        for key, val in asp_sent_dict.items():
            if key in tokens:
                new_label = label.replace(key+" B-ASP -1", key+" B-ASP "+val)
                data_lines += [new_label]
                data_lines += [str(ids[0])+"\n\n"]
            else:
                for ii in range(2,max_asp_len+1):
                    for no,tok in enumerate(tokens):
                        new_tok = " ".join(tokens[no:no+ii])
                        if new_tok == key:
                            new_label = label.replace(tokens[no]+" B-ASP -1",tokens[no]+" B-ASP "+val)
                            for xx in range(1,ii):
                                new_label = new_label.replace(tokens[no+xx]+" I-ASP -1",tokens[no+xx]+" I-ASP "+val)

                            data_lines += [new_label]
                            data_lines += [str(ids[0])+"\n\n"]

    return data_lines

# %%
dat_data = dat_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/ARTS-REST/test.dat","w") as f:
    f.write(''.join(dat_data))

# %% [markdown]
# # Create GRACEtxt

# %%
import nltk

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('conll2000')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Create chunks and pos tags. Source: https://towardsdatascience.com/chunking-in-nlp-decoded-b4a71b2b4e24

# %%
from nltk.tag import UnigramTagger, BigramTagger
from nltk.chunk import ChunkParserI
from nltk.chunk.util import tree2conlltags, conlltags2tree
from nltk.corpus import conll2000

# %%
def conll_tag_chunks(chunk_sents):
    tagged_sents = [tree2conlltags(tree) for tree in chunk_sents]
    return [[(t, c) for (w, t, c) in sent] for sent in tagged_sents]
    
def combined_tagger(train_data, taggers, backoff=None):
    for tagger in taggers:
        backoff = tagger(train_data, backoff=backoff)
    return backoff

class NGramTagChunker(ChunkParserI):

    def __init__(self,train_sentences,tagger_classes=[UnigramTagger,BigramTagger]):
        train_sent_tags=conll_tag_chunks(train_sentences)
        self.chunk_tagger=combined_tagger(train_sent_tags,tagger_classes)
    
    def parse(self,tagged_sentence):
        if not tagged_sentence:
            return None
        pos_tags=[tag for word, tag in tagged_sentence]
        chunk_pos_tags=self.chunk_tagger.tag(pos_tags)
        chunk_tags=[chunk_tag for (pos_tag,chunk_tag) in chunk_pos_tags]
        wpc_tags=[(word,pos_tag,chunk_tag) for ((word,pos_tag),chunk_tag) in zip(tagged_sentence,chunk_tags)]
        return conlltags2tree(wpc_tags)

# %%
data = conll2000.chunked_sents()
ntc = NGramTagChunker(data)

# %% [markdown]
# Convert tags into BIOES scheme. Source: https://gist.github.com/allanj/5ad206f7f4645c0269b68fb2065712f4

# %%
def iob_iobes(tags):
    """
    IOB2 (BIO) -> IOBES
    """
    new_tags = []
    for i, tag in enumerate(tags):
        if tag == 'O':
            new_tags.append(tag)
        elif tag.split('-')[0] == 'B':
            if i + 1 != len(tags) and \
                    tags[i + 1].split('-')[0] == 'I':
                new_tags.append(tag)
            else:
                new_tags.append(tag.replace('B-', 'S-'))
        elif tag.split('-')[0] == 'I':
            if i + 1 < len(tags) and \
                    tags[i + 1].split('-')[0] == 'I':
                new_tags.append(tag)
            else:
                new_tags.append(tag.replace('I-', 'E-'))
        else:
            raise Exception('Invalid IOB format!')
    return new_tags

# %%
def grace_txt_maker(df):
    
    data_lines = []
    sent_freq = df.text.value_counts()

    for text,freq in sent_freq.items():

        tokens = nltk.word_tokenize(text)

        # correct tokens
        for no,tok in enumerate(tokens):
            if tok[-1:] == "-" and len(tok)>2:
                tokens[no] = tok[:-1]
            if tok[:1] == "'" and len(tok)>3:
                tokens[no] = tok[1:]
            if tok in ["'","(",")"]:
                tokens.remove(tok)

        # create pos tags
        pos_tags = nltk.pos_tag(tokens)

        # create chunk/phrase tags
        full_tags = tree2conlltags(ntc.parse(pos_tags))
        chunks_list = [full_tags[ii][2] for ii in range(len(full_tags))]
        new_chunks = iob_iobes(chunks_list)

        text_lines = list(locate(list(df.text), lambda a: a == text))

        # create aspect-polarity dict
        asp_sent_dict = {}
        max_asp_len = 0
        ids = []
        for line in text_lines:
            ids += [df.loc[line,"id"]]
            aspect = df.loc[line,"term"]
            if aspect != None:
                asp_sent_dict[aspect] = df.loc[line,"polarity"].upper()
                if len(aspect.split()) > max_asp_len:
                    max_asp_len = len(aspect.split())

        label = ""
        # check for one-word-aspects
        for pos,tok in enumerate(tokens):
            label += tok + " " + pos_tags[pos][1] + " " + new_chunks[pos]
            if tok in asp_sent_dict.keys():
                label +=  " B_AP " + asp_sent_dict[tok] + " B_AP+" + asp_sent_dict[tok] + "\n"
            else:
                label += " O O O \n"

        # check for multi-word-aspects
        for ii in range(2,max_asp_len+1):
            for no,tok in enumerate(tokens):
                new_tok = " ".join(tokens[no:no+ii])
                if new_tok not in tokens and new_tok in asp_sent_dict.keys():
                    new_pol = asp_sent_dict[new_tok]
                    label = label.replace(tokens[no]+ " " + pos_tags[no][1] + " " + new_chunks[no] + " O O O \n",
                                          tokens[no]+ " " + pos_tags[no][1] + " " + new_chunks[no] + " B_AP " + \
                                          new_pol + " B_AP+" + new_pol + "\n")
                    for xx in range(1,ii):
                        label = label.replace(tokens[no+xx] + " " + pos_tags[no+xx][1] + " " + new_chunks[no+xx] + " O O O \n",
                                          tokens[no+xx]+ " " + pos_tags[no+xx][1] + " " + new_chunks[no+xx] + " I_AP " + \
                                          new_pol + " I_AP+" + new_pol + "\n")

        assert len(set(ids)) == 1
        label += str(ids[0]) + "\n"
        data_lines += [label]

    return data_lines

# %%
grace_txt_data = grace_txt_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/ARTS-REST/grace_test.txt","w") as f:
    f.write('\n'.join(grace_txt_data))
