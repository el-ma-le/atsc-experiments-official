# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Data Import

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %%
parsedXML = ET.parse("/content/drive/My Drive/Masterarbeit/Data/Original/MAMS/mams_train.xml")

# %%
aspect_number = 12

# %%
dfcols = ['id','text']
for ii in range(1,aspect_number):
    dfcols.append("aspect_term_{}".format(ii))
    dfcols.append("aspect_polarity_{}".format(ii))
    dfcols.append("aspect_from_{}".format(ii))
    dfcols.append("aspect_to_{}".format(ii))          
df = pd.DataFrame(columns=dfcols)

for sentence in parsedXML.getroot():
    id = sentence.attrib.get('id')
    text = sentence.find('text').text
    line = [id,text]

    for asp in sentence.iter('aspectTerm'):
        term = asp.attrib.get("term")
        pol = asp.attrib.get("polarity")
        a_from = asp.attrib.get("from")
        a_to = asp.attrib.get("to")

        line += [term, pol, a_from, a_to]

    if len(line) < len(dfcols):
        pads = [None] * (len(dfcols)-len(line))
        line += pads
    
    df = df.append(pd.Series(line, index=dfcols), ignore_index=True)

# %%
df
# Out:
#         id  ... aspect_to_11
# 0     None  ...         None
# 1     None  ...         None
# 2     None  ...         None
# 3     None  ...         None
# 4     None  ...         None
# ...    ...  ...          ...
# 4292  None  ...         None
# 4293  None  ...         None
# 4294  None  ...         None
# 4295  None  ...         None
# 4296  None  ...         None
#
# [4297 rows x 46 columns]

# %% [markdown]
# # Drop duplicates

# %%
cols_wo_id = df.columns
cols_wo_id = cols_wo_id.drop("id")
df[df.duplicated(cols_wo_id, keep=False)].sort_values("text")
# Out:
# Empty DataFrame
# Columns: [id, text, aspect_term_1, aspect_polarity_1, aspect_from_1, aspect_to_1, aspect_term_2, aspect_polarity_2, aspect_from_2, aspect_to_2, aspect_term_3, aspect_polarity_3, aspect_from_3, aspect_to_3, aspect_term_4, aspect_polarity_4, aspect_from_4, aspect_to_4, aspect_term_5, aspect_polarity_5, aspect_from_5, aspect_to_5, aspect_term_6, aspect_polarity_6, aspect_from_6, aspect_to_6, aspect_term_7, aspect_polarity_7, aspect_from_7, aspect_to_7, aspect_term_8, aspect_polarity_8, aspect_from_8, aspect_to_8, aspect_term_9, aspect_polarity_9, aspect_from_9, aspect_to_9, aspect_term_10, aspect_polarity_10, aspect_from_10, aspect_to_10, aspect_term_11, aspect_polarity_11, aspect_from_11, aspect_to_11]
# Index: []

# %%
df.drop_duplicates(cols_wo_id, ignore_index=True,inplace=True)

# %%
text_counts = df.text.value_counts()
text_counts[:10]
# Out:
# The waiter placed the wrong entree in front of us each time.                                                                                                                                   1
# We get our beers and then are told from a confuzed waitress that she realized that she can't give us the happy hour drink prices if we are not sitting at the bar.                             1
# In the middle of dessert, the waitress silently passes by and drops the check.                                                                                                                 1
# Upon his arrival the staff checked in his bags and put them in the storage room, but when my bf asked for a check-in ticket, the host refused to give one and threw the bags back at us.       1
# In summer, the small outdoor garden is an ideal place to sip coffee while reading under a canopy of trees and sky.                                                                             1
# The lobster is good but over-priced; go for lunch and it's only $35 and served prixe-fix with all the trimmings.                                                                               1
# The food wasn't impressive either- I was expecting huge portions, but my lobster ravioli was only 4 medium sized pieces, and I've tasted better at other restaurants.                          1
# the foods so tasty(the soup maybe a little blandbut ill forgive them only because everything else is out of this world.                                                                        1
# I asked one of the more elderly managers what we were eating and he joked that he didn't really know so he referred someone else to us who basically repeated what was written in the menu.    1
# I sometimes go here when in the area and though the food is always great, the Basil Chicken and Shrimp Tempura roll in particular, the service has much to be desired.                         1
# Name: text, dtype: int64

# %% [markdown]
# # First Descriptive Analysis

# %% [markdown]
# ## Aspects per sentence

# %%
pol_cols = ["aspect_polarity_"+str(ii) for ii in range(1,aspect_number)]

# %%
prev = 0
total_asp = 0
for no, col in enumerate(pol_cols):

    if col != "aspect_polarity_1":
        print("sentences with exactly ", no, "aspects:", prev - sum(df[col].value_counts()))
        total_asp += no * (prev - sum(df[col].value_counts()))

    if col == "aspect_polarity_"+str(aspect_number-1):
        print("sentences with exactly ", no+1, "aspects:", sum(df[col].value_counts()))
        total_asp += (no+1) * sum(df[col].value_counts())

    prev = sum(df[col].value_counts())

print("total no of aspects: ", total_asp)
# Out:
# sentences with exactly  1 aspects: 0
# sentences with exactly  2 aspects: 2568
# sentences with exactly  3 aspects: 1169
# sentences with exactly  4 aspects: 364
# sentences with exactly  5 aspects: 126
# sentences with exactly  6 aspects: 48
# sentences with exactly  7 aspects: 13
# sentences with exactly  8 aspects: 6
# sentences with exactly  9 aspects: 1
# sentences with exactly  10 aspects: 1
# sentences with exactly  11 aspects: 1
# total no of aspects:  11186

# %% [markdown]
# ## Sentiment Frequency

# %%
df_pol = df.loc[:,pol_cols]
df_pol_counts = df_pol.apply(pd.Series.value_counts)
df_pol_counts.sum(axis=1)
# Out:
# negative    2764.0
# neutral     5042.0
# positive    3380.0
# dtype: float64

# %%
sum(df_pol_counts.sum(axis=1))
# Out:
# 11186.0

# %% [markdown]
# ## Sentences with more than one aspect

# %%
multi_counter = 0
for line in df.index:
    sentiment_list = []
    for col in pol_cols:
        if df.loc[line,col] != None:
            sentiment_list += [df.loc[line,col]]
    if len(set(sentiment_list)) > 1:
        multi_counter += 1
multi_counter
# Out:
# 4297

# %% [markdown]
# # Remove "conflict"

# %%
for line in range(len(df)):
    for col in pol_cols:
        if df.loc[line,col] == "conflict":
            df.loc[line,col] = None
            number = col[-1:]
            df.loc[line,"aspect_term_"+str(number)] = None
            df.loc[line,"aspect_to_"+str(number)] = None
            df.loc[line,"aspect_from_"+str(number)] = None

# %%
df
# Out:
#         id  ... aspect_to_11
# 0     None  ...         None
# 1     None  ...         None
# 2     None  ...         None
# 3     None  ...         None
# 4     None  ...         None
# ...    ...  ...          ...
# 4292  None  ...         None
# 4293  None  ...         None
# 4294  None  ...         None
# 4295  None  ...         None
# 4296  None  ...         None
#
# [4297 rows x 46 columns]

# %% [markdown]
# # Check for wrong positions

# %%
mistakes = []
for ii in range(len(df)):
    for xx in range(1,aspect_number):
        asp_col = "aspect_term_"+str(xx)
        from_col = "aspect_from_"+str(xx)
        to_col = "aspect_to_"+str(xx)
        actual_term = df.loc[ii,asp_col]
        if actual_term != None:
            pos_term = df.text[ii][int(df.loc[ii,from_col]):int(df.loc[ii,to_col])]
            if actual_term != pos_term:
                mistakes += [ii]
                print(actual_term, pos_term)
mistakes
# Out:
# []

# %% [markdown]
# # Check for wrong aspect terms

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
for ii in range(len(df)):
    tokens = nltk.word_tokenize(df.text[ii])
    for xx in range(1,aspect_number):
        actual_term = df.loc[ii,"aspect_term_"+str(xx)]
        if actual_term != None:
            for asp_part in nltk.word_tokenize(actual_term):
                if asp_part not in tokens and asp_part+"-" not in tokens:
                    print(ii,"-",xx,":",tokens)
                    print(actual_term, asp_part)
# Out:
# 1191 - 2 : ['I', 'liked', 'the', 'beer', 'selection', '!']
# beer s s
# 1203 - 4 : ['No', 'table', 'space', 'and', 'one', 'of', 'the', 'angry', 'neighbors', 'decided', 'to', 'take', 'matters', 'into', 'his', 'own', 'hands', 'by', 'throwing', 'a', 'bucket', 'of', 'water', 'out', 'his', 'window', 'and', 'onto', 'the', 'patrons', 'waiting', 'for', 'their', 'tables', '.']
# table s s
# 1535 - 1 : ['My', 'only', 'complaint', 'might', 'be', 'the', 'beer', 'selection', '-', 'they', 'did', "n't", 'really', 'have', 'any', 'dark', 'beers', ',', 'which', 'I', 'like', 'to', 'have', 'with', 'a', 'steak', '.']
# beer s s
# 1594 - 4 : ['I', 'tried', 'the', 'Crab', 'Croquettes', '(', 'delicious', ',', 'and', 'yes', ',', 'the', 'sauce', 'IS', 'hot', ')', 'and', 'the', 'Salade', 'Jumelle', '(', 'a', 'good', ',', 'basic', 'mesculen', 'salad', ')', '.']
# Salad Salad
# 1773 - 3 : ['Place', 'was', 'empty', ',', 'waitress', 'was', 'rude', ',', 'told', 'us', 'that', 'even', 'though', 'there', 'were', 'drink', 'specials', 'at', 'the', 'bar', '(', '2', 'for', '1', 'margaritas', ')', ',', 'we', 'could', "n't", 'have', 'them', 'at', 'our', 'table', 'and', 'we', 'could', "n't", 'go', 'up', 'to', 'the', 'bar', 'to', 'get', 'drinks', '.']
# drink s s
# 2938 - 1 : ['Cheeses', 'get', 'short', 'shrift', 'by', 'waitstaff', ',', 'who', 'all', 'seem', 'hurried', '.']
# Cheese Cheese
# 3865 - 3 : ['For', 'dinner', 'I', 'order', 'linguine', 'w/', 'red', 'clam', 'sauce', ',', 'the', 'pasta', 'was', 'perfect', 'and', 'the', 'sauce', 'was', 'flavorful', 'but', 'the', 'clams', 'tasted', 'funny', 'so', 'I', 'ate', 'around', 'them', '.']
# clam s s
# 3903 - 3 : ['Gobo', "'s", 'scallion', 'pancakes', 'are', 'a', 'bit', 'dry', ',', 'and', 'the', 'beet', 'salad', 'is', 'low', 'on', 'beets', ',', 'but', 'the', 'majority', 'of', 'dishes', ',', 'especially', 'those', 'showcasing', 'vegetables', ',', 'are', 'delicious', 'in', 'their', 'simplicity', '.']
# beet s s

# %%
df.loc[1191,"aspect_term_2"] = "beer"
df.loc[1191,"aspect_to_2"] = str(int(df.loc[1191,"aspect_to_2"])-2)

# %%
df.loc[1203,"aspect_term_4"] = "table"
df.loc[1203,"aspect_to_4"] = str(int(df.loc[1203,"aspect_to_4"])-2)

# %%
df.loc[1535,"aspect_term_1"] = "beer"
df.loc[1535,"aspect_to_1"] = str(int(df.loc[1535,"aspect_to_1"])-2)

# %%
df.loc[1594,"aspect_term_4"] = "Salade"
df.loc[1594,"aspect_to_4"] = str(int(df.loc[1594,"aspect_to_4"])+1)

# %%
df.loc[1773,"aspect_term_3"] = "drink"
df.loc[1773,"aspect_to_3"] = str(int(df.loc[1773,"aspect_to_3"])-2)

# %%
df.loc[2938,"aspect_term_1"] = "Cheeses"
df.loc[2938,"aspect_to_1"] = str(int(df.loc[2938,"aspect_to_1"])+1)

# %%
df.loc[3865,"aspect_term_3"] = "clam"
df.loc[3865,"aspect_to_3"] = str(int(df.loc[3865,"aspect_to_3"])-2)

# %%
df.loc[3903,"aspect_term_3"] = "beet"
df.loc[3903,"aspect_to_3"] = str(int(df.loc[3903,"aspect_to_3"])-2)

# %% [markdown]
# Re-check for wrong positions

# %%
mistakes = []
for ii in range(len(df)):
    for xx in range(1,aspect_number):
        asp_col = "aspect_term_"+str(xx)
        from_col = "aspect_from_"+str(xx)
        to_col = "aspect_to_"+str(xx)
        actual_term = df.loc[ii,asp_col]
        if actual_term != None:
            pos_term = df.text[ii][int(df.loc[ii,from_col]):int(df.loc[ii,to_col])]
            if actual_term != pos_term:
                mistakes += [ii]
                print(actual_term, pos_term)
mistakes
# Out:
# []

# %% [markdown]
# # Descriptive Analysis

# %% [markdown]
# ## Aspects per sentence

# %%
pol_cols = ["aspect_polarity_"+str(ii) for ii in range(1,aspect_number)]

# %%
prev = 0
total_asp = 0
for no, col in enumerate(pol_cols):

    if col != "aspect_polarity_1":
        print("sentences with exactly ", no, "aspects:", prev - sum(df[col].value_counts()))
        total_asp += no * (prev - sum(df[col].value_counts()))

    if col == "aspect_polarity_"+str(aspect_number-1):
        print("sentences with exactly ", no+1, "aspects:", sum(df[col].value_counts()))
        total_asp += (no+1) * sum(df[col].value_counts())

    prev = sum(df[col].value_counts())

print("total no of aspects: ", total_asp)
# Out:
# sentences with exactly  1 aspects: 0
# sentences with exactly  2 aspects: 2568
# sentences with exactly  3 aspects: 1169
# sentences with exactly  4 aspects: 364
# sentences with exactly  5 aspects: 126
# sentences with exactly  6 aspects: 48
# sentences with exactly  7 aspects: 13
# sentences with exactly  8 aspects: 6
# sentences with exactly  9 aspects: 1
# sentences with exactly  10 aspects: 1
# sentences with exactly  11 aspects: 1
# total no of aspects:  11186

# %% [markdown]
# ## Sentiment Frequency

# %%
df_pol = df.loc[:,pol_cols]
df_pol_counts = df_pol.apply(pd.Series.value_counts)
df_pol_counts.sum(axis=1)
# Out:
# negative    2764.0
# neutral     5042.0
# positive    3380.0
# dtype: float64

# %%
sum(df_pol_counts.sum(axis=1))
# Out:
# 11186.0

# %% [markdown]
# ## Sentences with more than one aspect

# %%
multi_counter = 0
for line in df.index:
    sentiment_list = []
    for col in pol_cols:
        if df.loc[line,col] != None:
            sentiment_list += [df.loc[line,col]]
    if len(set(sentiment_list)) > 1:
        multi_counter += 1
multi_counter
# Out:
# 4297

# %% [markdown]
# # Save as xml

# %%
def xml_maker(df,aspect_number):

    root = ET.Element('sentences')

    for line in df.index:
        name = "sentence"
        entry = ET.SubElement(root, name)
        entry.set("id", str(df["id"][line]))

        text_child = ET.SubElement(entry, "text")
        text_child.text = str(df["text"][line])

        asp_child = ET.SubElement(entry, "aspectTerms")
        for xx in range(1,aspect_number):
            if df.loc[line,"aspect_term_"+str(xx)] != None:
                asp_subchild = ET.SubElement(asp_child, "aspectTerm")
                asp_subchild.set("from",str(df["aspect_from_"+str(xx)][line]))
                asp_subchild.set("polarity",str(df["aspect_polarity_"+str(xx)][line]))
                asp_subchild.set("term",str(df["aspect_term_"+str(xx)][line]))
                asp_subchild.set("to",str(df["aspect_to_"+str(xx)][line]))

    return ET.tostring(root)

# %%
xml_data = xml_maker(df,aspect_number)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/MAMS/train.xml","w") as f:
    f.write(xml_data.decode('utf-8'))

# %% [markdown]
# # Create xml.seg

# %%
def pol_to_no(sentiment):
  
    if sentiment == "positive":
        pol = 1
    elif sentiment == "negative":
        pol = -1
    elif sentiment == "neutral":
        pol = 0

    return str(pol)

# %%
def xml_seg_maker(df):

    df_wo_id = df.drop(columns="id", axis=1, inplace=False)
    df_wo_id.reset_index(drop=True, inplace=True)
    data_lines = []

    for ii in df_wo_id.index:

        line = list(df_wo_id.loc[ii])
        o_text = line[0]
        aspects = [line[xx] for xx in range(1,len(df_wo_id.loc[0]),4) if line[xx] != None]
        pols = [line[xx] for xx in range(2,len(df_wo_id.loc[0]),4) if line[xx] != None]

        for asp in range(len(aspects)):
            text = o_text.replace(aspects[asp],'$T$')
            pol = pol_to_no(pols[asp])

            data_lines += [text,aspects[asp],pol]
    
    return data_lines

# %%
xml_seg_data = xml_seg_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/MAMS/train.xml.seg","w") as f:
    f.write('\n'.join(xml_seg_data))

# %% [markdown]
# # Create BERT+txt

# %%
asp_cols = ["aspect_term_"+str(ii) for ii in range(1,aspect_number)]

# %%
def sent_conv(sentiment):

    if sentiment == "positive":
        return "POS"
    elif sentiment == "negative":
        return "NEG"
    elif sentiment == "neutral":
        return "NEU"

# %%
def txt_maker(df):

    data_lines = []

    for line in df.index:

        text = df.loc[line,"text"]
        tokens = nltk.word_tokenize(text)

        # correct tokens
        for no,tok in enumerate(tokens):
            if tok[-1:] == "-" and len(tok)>2:
                tokens[no] = tok[:-1]
            if tok[:1] == "'" and len(tok)>3:
                tokens[no] = tok[1:]
            if tok in ["'","(",")"]:
                tokens.remove(tok)

        # create aspect-polarity dict
        asp_sent_dict = {}
        max_asp_len = 0
        for col in range(len(asp_cols)):
            aspect = df.loc[line,asp_cols[col]]
            if aspect != None:
                asp_sent_dict[aspect] = sent_conv(df.loc[line,pol_cols[col]])
                if len(aspect.split()) > max_asp_len:
                    max_asp_len = len(aspect.split())


        label = ""
        # check for one-word-aspects
        for tok in tokens:
            if tok in asp_sent_dict.keys():
                label += tok + "=T-" + asp_sent_dict[tok] + " "
            else:
                label += tok + "=O "
        label = label[:-1]

        # check for multi-word-aspects
        for ii in range(2,max_asp_len+1):
            for no,tok in enumerate(tokens):
                new_tok = " ".join(tokens[no:no+ii])
                if new_tok in asp_sent_dict.keys():
                    new_pol = asp_sent_dict[new_tok]
                    old_label = " ".join([tokens[no+xx]+"=O" for xx in range(ii) if no+xx < len(tokens)])
                    new_label = " ".join([tokens[no+xx]+"=T-"+new_pol for xx in range(ii) if no+xx < len(tokens)])
                    label = label.replace(old_label, new_label)
  
        data_lines += [text+"####"+label]

    return data_lines

# %%
txt_data = txt_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/MAMS/train.txt","w") as f:
    f.write('\n'.join(txt_data))

# %% [markdown]
# # Create RGATjson

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading https://files.pythonhosted.org/packages/50/ae/a70a58ce6b4e2daad538688806ee0f238dbe601954582a74ea57cde6c532/stanza-1.2-py3-none-any.whl (282kB)
#      |████████████████████████████████| 286kB 8.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.8.1+cu101)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (56.1.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Installing collected packages: stanza
# Successfully installed stanza-1.2

# %%
import stanza

# %%
stanza.download('en')
nlp = stanza.Pipeline('en', processors='tokenize,pos,lemma,depparse')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 25.3MB/s]
# 2021-05-10 07:26:30 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|██████████| 411M/411M [01:59<00:00, 3.45MB/s]
# 2021-05-10 07:28:39 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-05-10 07:28:39 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# | depparse  | combined |
# ========================
#
# 2021-05-10 07:28:39 INFO: Use device: cpu
# 2021-05-10 07:28:39 INFO: Loading: tokenize
# 2021-05-10 07:28:40 INFO: Loading: pos
# 2021-05-10 07:28:40 INFO: Loading: lemma
# 2021-05-10 07:28:40 INFO: Loading: depparse
# 2021-05-10 07:28:40 INFO: Done loading processors!

# %%
from more_itertools import locate

# %% [markdown]
# ## in case of creating for the first time

# %%
import json

# %%
def json_make_pos(df):
   
    manual_pos = {}

    for ii in df.index:
        
        new_dict = {}
        text = df.loc[ii,"text"]
        tokens = [token.text for sentence in nlp(text).sentences for token in sentence.tokens]
        
        new_dict["aspects"] = []
        for xx in range(1,aspect_number):         
            if df.loc[ii,"aspect_term_"+str(xx)] != None:
                asp_dict = {}   
                term = df.loc[ii,"aspect_term_"+str(xx)]

                # construct aspect position on token level
                asp_toks = [token.text for sentence in nlp(term).sentences for token in sentence.tokens]
                asp_ind = [list(locate(tokens, lambda a: a == tok)) for tok in asp_toks]

                # for aspects appearing only once in text, take the correct position
                # otherwise set to None
                if len(asp_ind[0]) == 1:
                    from_index = asp_ind[0][0]
                else:
                    from_index = None
                if len(asp_ind[-1]) == 1:
                    to_index = asp_ind[-1][0] 
                else: 
                    to_index = None

                # if both start and end pos are unknown, 
                # e.g. for single-word aspects, 
                # take character positions for help
                if from_index == None and to_index == None and len(asp_ind[0]) != 0:
                    print(ii, ": ", text)
                    print("original term: ",term)
                    all_char_from = [i for i in range(len(text)) if text.startswith(asp_toks[0], i)]
                    print("all start chars: ",all_char_from)
                    corr_char_from = int(df.loc[ii, "aspect_from_"+str(xx)])
                    print("correct start char: ",corr_char_from)
                    print("text beginning at correct start char: ", text[corr_char_from:])
                    print("tokens: ",tokens)
                    print("original asp tokens: ", asp_toks)
                    print("original asp indices: ",asp_ind)
                    if corr_char_from == max(all_char_from):
                        from_index = asp_ind[0][-1]
                    elif corr_char_from == min(all_char_from):
                        from_index = asp_ind[0][0]

                # in case of missing start/end positions,
                # try to find "to"/"from" using aspect token number as distance
                if from_index == None and to_index != None:
                    from_index = to_index - len(asp_toks) +1
                if to_index == None and from_index != None:
                    to_index = from_index + len(asp_toks) -1

                # correct tokenization errors in aspect term tokenization
                if from_index == None or to_index == None or asp_toks != tokens[from_index:to_index+1]:

                    print("Tokenization Error in line ",ii,"!")
                    for pos, tok in enumerate(tokens):
                        print(pos, tok)
                    print("aspect term: ", term)
                    print("original asp tokens: ", asp_toks)

                    from_index = int(input("start position?"))
                    to_index = int(input("end position?"))

                    # add manually stated positions to dict for reproducibility
                    manual_pos[text] = {}
                    manual_pos[text][term] = {}
                    manual_pos[text][term]["from"] = from_index
                    manual_pos[text][term]["to"] = to_index
                    print(manual_pos)

                    print("Final aspect tokens: ", tokens[from_index:to_index+1])

                asp_dict["from"] = from_index
                asp_dict["to"] = to_index + 1

    with open("/content/drive/My Drive/Masterarbeit/Data/preprocessing/aspect_positions/mams_train.json","w") as f:
        json.dump(manual_pos, f)

json_make_pos(df)
# Out:
# Tokenization Error in line  62 !
# 0 The
# 1 menu
# 2 features
# 3 mild
# 4 versions
# 5 of
# 6 Lone
# 7 Star
# 8 state
# 9 favorites
# 10 ,
# 11 from
# 12 double
# 13 -
# 14 basted
# 15 baby
# 16 back
# 17 ribs
# 18 and
# 19 steak
# 20 fajitas
# 21 to
# 22 red-
# 23 beef
# 24 chili
# 25 and
# 26 deep
# 27 -
# 28 fried
# 29 onions
# 30 .
# aspect term:  red-beef chili
# original asp tokens:  ['red', '-', 'beef', 'chili']
# start position?22
# end position?24
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}}
# Final aspect tokens:  ['red-', 'beef', 'chili']
# Tokenization Error in line  109 !
# 0 Staple
# 1 entrees
# 2 like
# 3 moussaka
# 4 more
# 5 than
# 6 make
# 7 the
# 8 grade
# 9 ,
# 10 but
# 11 the
# 12 selection
# 13 of
# 14 clay
# 15 pot-cooked
# 16 dishes
# 17 --
# 18 tender
# 19 lamb
# 20 with
# 21 orzo
# 22 ,
# 23 or
# 24 fish
# 25 of
# 26 the
# 27 day
# 28 with
# 29 eggplant
# 30 and
# 31 zucchini--
# 32 take
# 33 comfort
# 34 food
# 35 to
# 36 a
# 37 new
# 38 level
# 39 .
# aspect term:  eggplant and zucchini
# original asp tokens:  ['eggplant', 'and', 'zucchini']
# start position?29
# end position?31
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}}
# Final aspect tokens:  ['eggplant', 'and', 'zucchini--']
# 291 :  The lengthy menu includes the likes of mee krob (glass noodles with shrimp, chicken and pork in plum sauce), nur-yang-num-tok (barbecued flank steak served with a spicy sauce), pork with chili and basil leaves and spicy, bean curd coconut milk soup.
# original term:  pork in plum sauce
# all start chars:  [88, 177]
# correct start char:  88
# text beginning at correct start char:  pork in plum sauce), nur-yang-num-tok (barbecued flank steak served with a spicy sauce), pork with chili and basil leaves and spicy, bean curd coconut milk soup.
# tokens:  ['The', 'lengthy', 'menu', 'includes', 'the', 'likes', 'of', 'mee', 'krob', '(', 'glass', 'noodles', 'with', 'shrimp', ',', 'chicken', 'and', 'pork', 'in', 'plum', 'sauce', ')', ',', 'nur-yang', '-', 'num', '-tok', '(', 'barbecued', 'flank', 'steak', 'served', 'with', 'a', 'spicy', 'sauce', ')', ',', 'pork', 'with', 'chili', 'and', 'basil', 'leaves', 'and', 'spicy', ',', 'bean', 'curd', 'coconut', 'milk', 'soup', '.']
# original asp tokens:  ['pork', 'in', 'plum', 'sauce']
# original asp indices:  [[17, 38], [18], [19], [20, 35]]
# Tokenization Error in line  426 !
# 0 Also
# 1 the
# 2 Ka-Choori
# 3 appetizer
# 4 (
# 5 vegetarian
# 6 goodness
# 7 )
# 8 and
# 9 the
# 10 Chicken
# 11 Makhni
# 12 (
# 13 Indian
# 14 for
# 15 Butter
# 16 Chicken
# 17 ,
# 18 American
# 19 for
# 20 FATTENING
# 21 AS
# 22 HECK
# 23 )
# 24 is
# 25 delish
# 26 .
# aspect term:  Ka-Choori appetizer
# original asp tokens:  ['Ka-', 'Choori', 'appetizer']
# start position?2
# end position?3
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}}
# Final aspect tokens:  ['Ka-Choori', 'appetizer']
# Tokenization Error in line  491 !
# 0 The
# 1 Bliss
# 2 Bowl
# 3 -
# 4 -
# 5 a
# 6 large
# 7 portion
# 8 of
# 9 brown
# 10 rice
# 11 ,
# 12 beans
# 13 ,
# 14 kale
# 15 ,
# 16 carrots
# 17 ,
# 18 broccoli
# 19 ,
# 20 cauliflower
# 21 ,
# 22 tofu
# 23 ,
# 24 seaweed
# 25 and
# 26 tahini-
# 27 -
# 28 is
# 29 the
# 30 specialty
# 31 of
# 32 the
# 33 house
# 34 .
# aspect term:  tahini
# original asp tokens:  ['tahini']
# start position?26
# end position?26
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}}
# Final aspect tokens:  ['tahini-']
# Tokenization Error in line  495 !
# 0 The
# 1 MooShu
# 2 spring
# 3 rolls
# 4 were
# 5 tasty
# 6 ,
# 7 steamed
# 8 dumplings
# 9 alright
# 10 .
# aspect term:  MooShu spring rolls
# original asp tokens:  ['Moo', 'Shu', 'spring', 'rolls']
# start position?1
# end position?3
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}}
# Final aspect tokens:  ['MooShu', 'spring', 'rolls']
# 750 :  the wait for our drinks, appetizers and food was very long, the food was mediocre, and it was a bit pricey.
# original term:  food
# all start chars:  [40, 64]
# correct start char:  40
# text beginning at correct start char:  food was very long, the food was mediocre, and it was a bit pricey.
# tokens:  ['the', 'wait', 'for', 'our', 'drinks', ',', 'appetizers', 'and', 'food', 'was', 'very', 'long', ',', 'the', 'food', 'was', 'mediocre', ',', 'and', 'it', 'was', 'a', 'bit', 'pricey', '.']
# original asp tokens:  ['food']
# original asp indices:  [[8, 14]]
# 893 :  The Bollos appetizer, this deliciouss black bean, roasted corn fritter w/ a tsty dipping sauce and the Mahi Mahi was grilled just right.
# original term:  Mahi Mahi
# all start chars:  [103, 108]
# correct start char:  103
# text beginning at correct start char:  Mahi Mahi was grilled just right.
# tokens:  ['The', 'Bollos', 'appetizer', ',', 'this', 'deliciouss', 'black', 'bean', ',', 'roasted', 'corn', 'fritter', 'w/', 'a', 'tsty', 'dipping', 'sauce', 'and', 'the', 'Mahi', 'Mahi', 'was', 'grilled', 'just', 'right', '.']
# original asp tokens:  ['Mahi', 'Mahi']
# original asp indices:  [[19, 20], [19, 20]]
# Tokenization Error in line  904 !
# 0 The
# 1 chef
# 2 /
# 3 owner
# 4 is
# 5 always
# 6 walking
# 7 around
# 8 making
# 9 sure
# 10 everyone
# 11 is
# 12 having
# 13 a
# 14 good
# 15 time
# 16 .
# aspect term:  chef/owner
# original asp tokens:  ['chef', '/owner']
# start position?1
# end position?3
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}}
# Final aspect tokens:  ['chef', '/', 'owner']
# Tokenization Error in line  1133 !
# 0 Yes
# 1 ,
# 2 hard
# 3 not
# 4 to
# 5 look
# 6 at
# 7 the
# 8 waitresses
# 9 (
# 10 and
# 11 they
# 12 're
# 13 really
# 14 good
# 15 servers
# 16 )
# 17 ,
# 18 but
# 19 as
# 20 I
# 21 'm
# 22 reminded
# 23 by
# 24 everyone
# 25 who
# 26 knows
# 27 Hooters
# 28 ,
# 29 they
# 30 do
# 31 n't
# 32 rank
# 33 anywhere
# 34 near
# 35 the
# 36 girls
# 37 at
# 38 the
# 39 Hooters
# 40 locations
# 41 South
# 42 of
# 43 the
# 44 ol
# 45 '
# 46 Mason
# 47 -Dixon
# 48 .
# aspect term:  Mason-Dixon
# original asp tokens:  ['Mason-Dixon']
# start position?46
# end position?47
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}}
# Final aspect tokens:  ['Mason', '-Dixon']
# Tokenization Error in line  1160 !
# 0 I
# 1 ordered
# 2 a
# 3 thin
# 4 -crust
# 5 individual
# 6 meat
# 7 pizza
# 8 which
# 9 was
# 10 big
# 11 enough
# 12 for
# 13 two
# 14 and
# 15 my
# 16 companion
# 17 ordered
# 18 pasta
# 19 with
# 20 pesto
# 21 .
# aspect term:  thin-crust individual meat pizza
# original asp tokens:  ['thin-crust', 'individual', 'meat', 'pizza']
# start position?3
# end position?7
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}}
# Final aspect tokens:  ['thin', '-crust', 'individual', 'meat', 'pizza']
# Tokenization Error in line  1169 !
# 0 I
# 1 had
# 2 the
# 3 lobster
# 4 ravioli--
# 5 good
# 6 size
# 7 portion
# 8 with
# 9 a
# 10 delicious
# 11 vodka
# 12 cream
# 13 sauce
# 14 .
# aspect term:  lobster ravioli
# original asp tokens:  ['lobster', 'ravioli']
# start position?3
# end position?4
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}}
# Final aspect tokens:  ['lobster', 'ravioli--']
# 1429 :  (Note: Price variations were listed nowhere--and I had asked for a to-go drink, deciding--after paying--to sit at a no-service counter until my drink cooled off.
# original term:  to-go drink
# all start chars:  [67, 104]
# correct start char:  67
# text beginning at correct start char:  to-go drink, deciding--after paying--to sit at a no-service counter until my drink cooled off.
# tokens:  ['(', 'Note', ':', 'Price', 'variations', 'were', 'listed', 'nowhere', '--', 'and', 'I', 'had', 'asked', 'for', 'a', 'to', '-', 'go', 'drink', ',', 'deciding', '-', '-', 'after', 'paying', '-', '-', 'to', 'sit', 'at', 'a', 'no-service', 'counter', 'until', 'my', 'drink', 'cooled', 'off', '.']
# original asp tokens:  ['to', '-', 'go', 'drink']
# original asp indices:  [[15, 27], [16, 21, 22, 25, 26], [17], [18, 35]]
# Tokenization Error in line  1530 !
# 0 When
# 1 we
# 2 got
# 3 our
# 4 food
# 5 ,
# 6 the
# 7 waitress
# 8 barely
# 9 said
# 10 a
# 11 word
# 12 as
# 13 she
# 14 placed
# 15 our
# 16 take
# 17 -
# 18 out
# 19 on
# 20 the
# 21 table
# 22 and
# 23 grabbed
# 24 the
# 25 check
# 26 .
# aspect term:  take-out
# original asp tokens:  ['take-out']
# start position?16
# end position?18
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}}
# Final aspect tokens:  ['take', '-', 'out']
# Tokenization Error in line  1698 !
# 0 That
# 1 ,
# 2 the
# 3 Peruvian
# 4 style
# 5 rotisserie
# 6 chicken
# 7 (
# 8 get
# 9 a
# 10 whole
# 11 one
# 12 )
# 13 and
# 14 a
# 15 side
# 16 dish
# 17 plus
# 18 do
# 19 n't
# 20 forget
# 21 -
# 22 chicha
# 23 moradas
# 24 :
# 25 a
# 26 refreshing
# 27 non-
# 28 alcoholic
# 29 drink
# 30 made
# 31 from
# 32 boiled
# 33 purple
# 34 corn
# 35 and
# 36 lime
# 37 juice
# 38 with
# 39 tiny
# 40 pear
# 41 cubes
# 42 and
# 43 a
# 44 bit
# 45 of
# 46 sugar
# 47 .
# aspect term:  non-alcoholic drink
# original asp tokens:  ['non-alcoholic', 'drink']
# start position?27
# end position?29
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}}
# Final aspect tokens:  ['non-', 'alcoholic', 'drink']
# 1711 :  The menu is slightly different from downtown, but they still have my favorites -- madai salad with hot sesame oil, shrimp kanzuri, the diamond roll, the crispy shrimp roll.
# original term:  shrimp roll
# all start chars:  [115, 160]
# correct start char:  160
# text beginning at correct start char:  shrimp roll.
# tokens:  ['The', 'menu', 'is', 'slightly', 'different', 'from', 'downtown', ',', 'but', 'they', 'still', 'have', 'my', 'favorites', '--', 'madai', 'salad', 'with', 'hot', 'sesame', 'oil', ',', 'shrimp', 'kanzuri', ',', 'the', 'diamond', 'roll', ',', 'the', 'crispy', 'shrimp', 'roll', '.']
# original asp tokens:  ['shrimp', 'roll']
# original asp indices:  [[22, 31], [27, 32]]
# 1727 :  For dessert I had the green tea tiramisu and ice cream- I loved both, my bf who doesn't really like green tea actually really liked the tiramisu.
# original term:  green tea tiramisu
# all start chars:  [22, 100]
# correct start char:  22
# text beginning at correct start char:  green tea tiramisu and ice cream- I loved both, my bf who doesn't really like green tea actually really liked the tiramisu.
# tokens:  ['For', 'dessert', 'I', 'had', 'the', 'green', 'tea', 'tiramisu', 'and', 'ice', 'cream', '-', 'I', 'loved', 'both', ',', 'my', 'bf', 'who', 'does', "n't", 'really', 'like', 'green', 'tea', 'actually', 'really', 'liked', 'the', 'tiramisu', '.']
# original asp tokens:  ['green', 'tea', 'tiramisu']
# original asp indices:  [[5, 23], [6, 24], [7, 29]]
# Tokenization Error in line  1927 !
# 0 We
# 1 had
# 2 reserved
# 3 space
# 4 one
# 5 one
# 6 side
# 7 of
# 8 the
# 9 bar
# 10 ,
# 11 but
# 12 when
# 13 the
# 14 staff
# 15 tried
# 16 to
# 17 force
# 18 the
# 19 Pre-
# 20 Fixe
# 21 on
# 22 all
# 23 15
# 24 members
# 25 of
# 26 the
# 27 party
# 28 to
# 29 stay
# 30 there
# 31 ,
# 32 we
# 33 moved
# 34 to
# 35 the
# 36 other
# 37 side
# 38 (
# 39 the
# 40 difference
# 41 in
# 42 decor
# 43 was
# 44 minimal
# 45 )
# 46 .
# aspect term:  Pre-Fixe
# original asp tokens:  ['Pre', '-', 'Fixe']
# start position?19
# end position?20
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}}
# Final aspect tokens:  ['Pre-', 'Fixe']
# 1977 :  The waiter poured our wine into my water glass, rolled his eyes when I asked for a new water, and definitely didn't offer to comp the wasted glass of wine.
# original term:  water glass
# all start chars:  [35, 87]
# correct start char:  35
# text beginning at correct start char:  water glass, rolled his eyes when I asked for a new water, and definitely didn't offer to comp the wasted glass of wine.
# tokens:  ['The', 'waiter', 'poured', 'our', 'wine', 'into', 'my', 'water', 'glass', ',', 'rolled', 'his', 'eyes', 'when', 'I', 'asked', 'for', 'a', 'new', 'water', ',', 'and', 'definitely', 'did', "n't", 'offer', 'to', 'comp', 'the', 'wasted', 'glass', 'of', 'wine', '.']
# original asp tokens:  ['water', 'glass']
# original asp indices:  [[7, 19], [8, 30]]
# 1977 :  The waiter poured our wine into my water glass, rolled his eyes when I asked for a new water, and definitely didn't offer to comp the wasted glass of wine.
# original term:  glass of wine
# all start chars:  [41, 141]
# correct start char:  141
# text beginning at correct start char:  glass of wine.
# tokens:  ['The', 'waiter', 'poured', 'our', 'wine', 'into', 'my', 'water', 'glass', ',', 'rolled', 'his', 'eyes', 'when', 'I', 'asked', 'for', 'a', 'new', 'water', ',', 'and', 'definitely', 'did', "n't", 'offer', 'to', 'comp', 'the', 'wasted', 'glass', 'of', 'wine', '.']
# original asp tokens:  ['glass', 'of', 'wine']
# original asp indices:  [[8, 30], [31], [4, 32]]
# Tokenization Error in line  2006 !
# 0 A
# 1 dining
# 2 beacon
# 3 in
# 4 an
# 5 otherwise
# 6 residential
# 7 4
# 8 or
# 9 5
# 10 block
# 11 radius
# 12 ,
# 13 Sorrel
# 14 pleases
# 15 on
# 16 every
# 17 course
# 18 --
# 19 from
# 20 the
# 21 cold
# 22 spicy
# 23 tomato
# 24 soup
# 25 and
# 26 beet
# 27 salad
# 28 starters
# 29 to
# 30 the
# 31 delectable
# 32 skate
# 33 ,
# 34 the
# 35 scallops
# 36 ,
# 37 or
# 38 steak
# 39 tartare
# 40 ,
# 41 straight
# 42 through
# 43 to
# 44 the
# 45 strange
# 46 but
# 47 tasty
# 48 melon
# 49 soup
# 50 or
# 51 flan
# 52 -
# 53 esque
# 54 orange
# 55 -
# 56 and
# 57 -
# 58 caramel
# 59 custard
# 60 (
# 61 so
# 62 bad
# 63 with
# 64 names
# 65 )
# 66 .
# aspect term:  orange-and-caramel
# original asp tokens:  ['orange', '-and-caramel']
# start position?54
# end position?58
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}}
# Final aspect tokens:  ['orange', '-', 'and', '-', 'caramel']
# Tokenization Error in line  2022 !
# 0 Sometimes
# 1 ,
# 2 the
# 3 take
# 4 -
# 5 out
# 6 and
# 7 seating
# 8 lines
# 9 can
# 10 be
# 11 long
# 12 ,
# 13 but
# 14 the
# 15 staff
# 16 help
# 17 move
# 18 things
# 19 along
# 20 .
# aspect term:  take-out
# original asp tokens:  ['take-out']
# start position?3
# end position?5
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}}
# Final aspect tokens:  ['take', '-', 'out']
# Tokenization Error in line  2142 !
# 0 As
# 1 soon
# 2 as
# 3 he
# 4 sat
# 5 ,
# 6 a
# 7 waiter
# 8 came
# 9 over
# 10 not
# 11 once
# 12 but
# 13 twice
# 14 ,
# 15 the
# 16 first
# 17 time
# 18 to
# 19 suggest
# 20 he
# 21 move
# 22 to
# 23 the
# 24 bar
# 25 b/c
# 26 our
# 27 large
# 28 booth
# 29 did
# 30 n't
# 31 accomodate
# 32 an
# 33 extra
# 34 person
# 35 ,
# 36 the
# 37 second
# 38 time
# 39 to
# 40 insist
# 41 he
# 42 move
# 43 .
# aspect term:  bar b/c
# original asp tokens:  ['bar', 'b/', 'c']
# start position?24
# end position?25
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}, "As soon as he sat, a waiter came over not once but twice, the first time to suggest he move to the bar b/c our large booth didn't accomodate an extra person, the second time to insist he move.": {'bar b/c': {'from': 24, 'to': 25}}}
# Final aspect tokens:  ['bar', 'b/c']
# Tokenization Error in line  2215 !
# 0 A
# 1 dish
# 2 of
# 3 chewy
# 4 smoked
# 5 seitan
# 6 evokes
# 7 Peking
# 8 duck
# 9 ,
# 10 while
# 11 an
# 12 entree
# 13 of
# 14 wide
# 15 green
# 16 -
# 17 tea
# 18 noodles
# 19 is
# 20 served
# 21 in
# 22 a
# 23 tasty
# 24 faux
# 25 Bolognese
# 26 sauce
# 27 .
# aspect term:  wide green-tea noodles
# original asp tokens:  ['wide', 'green-', 'tea', 'noodles']
# start position?14
# end position?18
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}, "As soon as he sat, a waiter came over not once but twice, the first time to suggest he move to the bar b/c our large booth didn't accomodate an extra person, the second time to insist he move.": {'bar b/c': {'from': 24, 'to': 25}}, 'A dish of chewy smoked seitan evokes Peking duck, while an entree of wide green-tea noodles is served in a tasty faux Bolognese sauce.': {'wide green-tea noodles': {'from': 14, 'to': 18}}}
# Final aspect tokens:  ['wide', 'green', '-', 'tea', 'noodles']
# Tokenization Error in line  2220 !
# 0 Though
# 1 weekend
# 2 nights
# 3 and
# 4 Sunday
# 5 brunch
# 6 draw
# 7 the
# 8 largest
# 9 crowds
# 10 ,
# 11 neighborhood
# 12 residents
# 13 master
# 14 this
# 15 vegan
# 16 menu
# 17 of
# 18 quinoa-
# 19 lentil
# 20 cakes
# 21 ,
# 22 seitan
# 23 piccata
# 24 ,
# 25 and
# 26 sweet
# 27 -
# 28 potato
# 29 pumpkin
# 30 pie
# 31 by
# 32 popping
# 33 in
# 34 daily
# 35 .
# aspect term:  quinoa-lentil cakes
# original asp tokens:  ['quinoa', '-', 'lentil', 'cakes']
# start position?18
# end position?20
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}, "As soon as he sat, a waiter came over not once but twice, the first time to suggest he move to the bar b/c our large booth didn't accomodate an extra person, the second time to insist he move.": {'bar b/c': {'from': 24, 'to': 25}}, 'A dish of chewy smoked seitan evokes Peking duck, while an entree of wide green-tea noodles is served in a tasty faux Bolognese sauce.': {'wide green-tea noodles': {'from': 14, 'to': 18}}, 'Though weekend nights and Sunday brunch draw the largest crowds, neighborhood residents master this vegan menu of quinoa-lentil cakes, seitan piccata, and sweet-potato pumpkin pie by popping in daily.': {'quinoa-lentil cakes': {'from': 18, 'to': 20}}}
# Final aspect tokens:  ['quinoa-', 'lentil', 'cakes']
# Tokenization Error in line  2253 !
# 0 Binegar
# 1 ,
# 2 soy
# 3 sauce
# 4 ,
# 5 pish
# 6 sauce
# 7 ,
# 8 gar
# 9 LIC
# 10 ,
# 11 ginger
# 12 ,
# 13 chicken
# 14 ,
# 15 lechon
# 16 ,
# 17 oh
# 18 man
# 19 ,
# 20 it
# 21 was
# 22 sooooooooooooooooooooooooooooooo
# 23 good
# 24 .
# aspect term:  garLIC, ginger, chicken
# original asp tokens:  ['garLIC', ',', 'ginger', ',', 'chicken']
# start position?8
# end position?13
# ...
# Final aspect tokens:  ['take', '-', 'out']
# Tokenization Error in line  3928 !
# 0 The
# 1 Food
# 2 The
# 3 French
# 4 -
# 5 Belgian
# 6 menu
# 7 is
# 8 small
# 9 ,
# 10 but
# 11 everything
# 12 on
# 13 it
# 14 is
# 15 satisfyingly
# 16 savory
# 17 ,
# 18 from
# 19 a
# 20 simple
# 21 pot
# 22 of
# 23 mussels
# 24 in
# 25 a
# 26 choice
# 27 of
# 28 sauces
# 29 (
# 30 beer
# 31 and
# 32 bacon
# 33 ,
# 34 creamy
# 35 mushroom
# 36 ,
# 37 or
# 38 white
# 39 wine
# 40 and
# 41 garlic
# 42 broth
# 43 )
# 44 ,
# 45 to
# 46 beef
# 47 stewed
# 48 with
# 49 beer
# 50 and
# 51 prunes
# 52 ;
# 53 from
# 54 a
# 55 juicy
# 56 croque
# 57 monsieur
# 58 and
# 59 beyond
# 60 .
# aspect term:  French-Belgian menu
# original asp tokens:  ['French', '-Belgian', 'menu']
# start position?3
# end position?6
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}, "As soon as he sat, a waiter came over not once but twice, the first time to suggest he move to the bar b/c our large booth didn't accomodate an extra person, the second time to insist he move.": {'bar b/c': {'from': 24, 'to': 25}}, 'A dish of chewy smoked seitan evokes Peking duck, while an entree of wide green-tea noodles is served in a tasty faux Bolognese sauce.': {'wide green-tea noodles': {'from': 14, 'to': 18}}, 'Though weekend nights and Sunday brunch draw the largest crowds, neighborhood residents master this vegan menu of quinoa-lentil cakes, seitan piccata, and sweet-potato pumpkin pie by popping in daily.': {'quinoa-lentil cakes': {'from': 18, 'to': 20}}, 'Binegar, soy sauce, pish sauce, garLIC, ginger, chicken, lechon, oh man, it was sooooooooooooooooooooooooooooooo good.': {'garLIC, ginger, chicken': {'from': 8, 'to': 13}}, "Don't bother looking at a menu- Shrimp cocktail, steak for 1,2,3, or more, creamed spinach and hash browns, and save room for the pecan pie and cheese cake, and don't forget the SCHLAG!!!!": {'menu- Shrimp cocktail': {'from': 6, 'to': 9}}, 'Only quibbles are so-so wine service, and while Prix-fix ...
# Final aspect tokens:  ['French', '-', 'Belgian', 'menu']
# Tokenization Error in line  4092 !
# 0 Although
# 1 the
# 2 tables
# 3 may
# 4 be
# 5 closely
# 6 situated
# 7 ,
# 8 the
# 9 candle
# 10 -
# 11 light
# 12 ,
# 13 food
# 14 -
# 15 quality
# 16 and
# 17 service
# 18 overcompensate
# 19 .
# aspect term:  candle-light
# original asp tokens:  ['candle', '-light']
# start position?9
# end position?11
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}, "As soon as he sat, a waiter came over not once but twice, the first time to suggest he move to the bar b/c our large booth didn't accomodate an extra person, the second time to insist he move.": {'bar b/c': {'from': 24, 'to': 25}}, 'A dish of chewy smoked seitan evokes Peking duck, while an entree of wide green-tea noodles is served in a tasty faux Bolognese sauce.': {'wide green-tea noodles': {'from': 14, 'to': 18}}, 'Though weekend nights and Sunday brunch draw the largest crowds, neighborhood residents master this vegan menu of quinoa-lentil cakes, seitan piccata, and sweet-potato pumpkin pie by popping in daily.': {'quinoa-lentil cakes': {'from': 18, 'to': 20}}, 'Binegar, soy sauce, pish sauce, garLIC, ginger, chicken, lechon, oh man, it was sooooooooooooooooooooooooooooooo good.': {'garLIC, ginger, chicken': {'from': 8, 'to': 13}}, "Don't bother looking at a menu- Shrimp cocktail, steak for 1,2,3, or more, creamed spinach and hash browns, and save room for the pecan pie and cheese cake, and don't forget the SCHLAG!!!!": {'menu- Shrimp cocktail': {'from': 6, 'to': 9}}, 'Only quibbles are so-so wine service, and while Prix-fix ...
# Final aspect tokens:  ['candle', '-', 'light']
# Tokenization Error in line  4092 !
# 0 Although
# 1 the
# 2 tables
# 3 may
# 4 be
# 5 closely
# 6 situated
# 7 ,
# 8 the
# 9 candle
# 10 -
# 11 light
# 12 ,
# 13 food
# 14 -
# 15 quality
# 16 and
# 17 service
# 18 overcompensate
# 19 .
# aspect term:  food-quality
# original asp tokens:  ['food-quality']
# start position?13
# end position?15
# {'The menu features mild versions of Lone Star state favorites, from double-basted baby back ribs and steak fajitas to red-beef chili and deep-fried onions.': {'red-beef chili': {'from': 22, 'to': 24}}, ' Staple entrees like moussaka more than make the grade, but the selection of clay pot-cooked dishes--tender lamb with orzo, or fish of the day with eggplant and zucchini--take comfort food to a new level.': {'eggplant and zucchini': {'from': 29, 'to': 31}}, 'Also the Ka-Choori appetizer (vegetarian goodness) and the Chicken Makhni (Indian for Butter Chicken, American for FATTENING AS HECK) is delish.': {'Ka-Choori appetizer': {'from': 2, 'to': 3}}, 'The Bliss Bowl--a large portion of brown rice, beans, kale, carrots, broccoli, cauliflower, tofu, seaweed and tahini--is the specialty of the house.': {'tahini': {'from': 26, 'to': 26}}, 'The MooShu spring rolls were tasty, steamed dumplings alright.': {'MooShu spring rolls': {'from': 1, 'to': 3}}, 'The chef/owner is always walking around making sure everyone is having a good time.': {'chef/owner': {'from': 1, 'to': 3}}, "Yes, hard not to look at the waitresses (and they're really good servers), but as I'm reminded by everyone who knows Hooters, they don't rank anywhere near the girls at the Hooters locations South of the ol' Mason-Dixon.": {'Mason-Dixon': {'from': 46, 'to': 47}}, 'I ordered a thin-crust individual meat pizza which was big enough for two and my companion ordered pasta with pesto.': {'thin-crust individual meat pizza': {'from': 3, 'to': 7}}, 'I had the lobster ravioli--good size portion with a delicious vodka cream sauce.': {'lobster ravioli': {'from': 3, 'to': 4}}, 'When we got our food, the waitress barely said a word as she placed our take-out on the table and grabbed the check.': {'take-out': {'from': 16, 'to': 18}}, "That, the Peruvian style rotisserie chicken (get a whole one) and a side dish plus don't forget - chicha moradas: a refreshing non-alcoholic drink made from boiled purple corn and lime juice with tiny pear cubes and a bit of sugar.": {'non-alcoholic drink': {'from': 27, 'to': 29}}, 'We had reserved space one one side of the bar, but when the staff tried to force the Pre-Fixe on all 15 members of the party to stay there, we moved to the other side (the difference in decor was minimal).': {'Pre-Fixe': {'from': 19, 'to': 20}}, 'A dining beacon in an otherwise residential 4 or 5 block radius, Sorrel pleases on every course--from the cold spicy tomato soup and beet salad starters to the delectable skate, the scallops, or steak tartare, straight through to the strange but tasty melon soup or flan-esque orange-and-caramel custard (so bad with names).': {'orange-and-caramel': {'from': 54, 'to': 58}}, 'Sometimes, the take-out and seating lines can be long, but the staff help move things along.': {'take-out': {'from': 3, 'to': 5}}, "As soon as he sat, a waiter came over not once but twice, the first time to suggest he move to the bar b/c our large booth didn't accomodate an extra person, the second time to insist he move.": {'bar b/c': {'from': 24, 'to': 25}}, 'A dish of chewy smoked seitan evokes Peking duck, while an entree of wide green-tea noodles is served in a tasty faux Bolognese sauce.': {'wide green-tea noodles': {'from': 14, 'to': 18}}, 'Though weekend nights and Sunday brunch draw the largest crowds, neighborhood residents master this vegan menu of quinoa-lentil cakes, seitan piccata, and sweet-potato pumpkin pie by popping in daily.': {'quinoa-lentil cakes': {'from': 18, 'to': 20}}, 'Binegar, soy sauce, pish sauce, garLIC, ginger, chicken, lechon, oh man, it was sooooooooooooooooooooooooooooooo good.': {'garLIC, ginger, chicken': {'from': 8, 'to': 13}}, "Don't bother looking at a menu- Shrimp cocktail, steak for 1,2,3, or more, creamed spinach and hash browns, and save room for the pecan pie and cheese cake, and don't forget the SCHLAG!!!!": {'menu- Shrimp cocktail': {'from': 6, 'to': 9}}, 'Only quibbles are so-so wine service, and while Prix-fix ...
# Final aspect tokens:  ['food', '-', 'quality']

# %% [markdown]
# ## in case of reproducing the dataset

# %%
def json_maker(df, manual_pos):
   
    new_data = []

    for ii in df.index:
        
        new_dict = {}
        text = df.loc[ii,"text"]

        tokens = [token.text for sentence in nlp(text).sentences for token in sentence.tokens]
        new_dict["token"] = tokens

        new_dict["pos"] = [word.xpos for sentence in nlp(text).sentences for word in sentence.words]
        new_dict["head"] = [str(word.head) for sentence in nlp(text).sentences for word in sentence.words]
        new_dict["deprel"] = [word.deprel for sentence in nlp(text).sentences for word in sentence.words]
        
        new_dict["aspects"] = []
        for xx in range(1,aspect_number):         
            if df.loc[ii,"aspect_term_"+str(xx)] != None:
                asp_dict = {}   
                term = df.loc[ii,"aspect_term_"+str(xx)]
                asp_dict["term"] = term
                asp_dict["polarity"] = df.loc[ii,"aspect_polarity_"+str(xx)]

                # construct aspect position on token level
                asp_toks = [token.text for sentence in nlp(term).sentences for token in sentence.tokens]
                asp_ind = [list(locate(tokens, lambda a: a == term)) for term in asp_toks]

                # for aspects appearing only once in text, take the correct position
                # otherwise set to None
                if len(asp_ind[0]) == 1:
                    from_index = asp_ind[0][0]
                else:
                    from_index = None
                if len(asp_ind[-1]) == 1:
                    to_index = asp_ind[-1][0] 
                else: 
                    to_index = None

                # if both start and end pos are unknown, 
                # e.g. for single-word aspects, 
                # take character positions for help
                if from_index == None and to_index == None and len(asp_ind[0]) != 0:

                    all_char_from = [i for i in range(len(text)) if text.startswith(asp_toks[0], i)]
                    corr_char_from = int(df.loc[ii, "aspect_from_"+str(xx)])

                    if corr_char_from == max(all_char_from):
                        from_index = asp_ind[0][-1]
                    elif corr_char_from == min(all_char_from):
                        from_index = asp_ind[0][0]

                # in case of missing start/end positions,
                # try to find "to"/"from" using aspect token number as distance
                if from_index == None and to_index != None:
                    from_index = to_index - len(asp_toks) +1
                if to_index == None and from_index != None:
                    to_index = from_index + len(asp_toks) -1

                # correct tokenization errors in aspect term tokenization
                if from_index == None or to_index == None or asp_toks != tokens[from_index:to_index+1]:
                    if text in manual_pos.keys() and term in manual_pos[text].keys():
                        from_index = manual_pos[text][term]["from"]
                        to_index = manual_pos[text][term]["to"]

                asp_dict["from"] = from_index
                asp_dict["to"] = to_index + 1

                new_dict["aspects"] += [asp_dict]
        
        new_data += [new_dict]

    return new_data

# %%
pos_obj = open("/content/drive/My Drive/Masterarbeit/Data/preprocessing/aspect_positions/mams_train.json")
loaded_pos = json.load(pos_obj)

json_data = json_maker(df, loaded_pos)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/MAMS/train.json","w") as f:
    json.dump(json_data, f)

# %% [markdown]
# # Create LCF-ATEPCdat

# %%
def pol_to_no_shifted(sentiment):
  
    if sentiment == "positive":
        pol = 2
    elif sentiment == "negative":
        pol = 0
    elif sentiment == "neutral":
        pol = 1

    return str(pol)

# %%
def dat_maker(df):
    
    data_lines = []

    for line in df.index:

        text = df.loc[line,"text"]
        tokens = nltk.word_tokenize(text)

        # correct tokens
        for no,tok in enumerate(tokens):
            if tok[-1:] == "-" and len(tok)>2:
                tokens[no] = tok[:-1]
            if tok[:1] == "'" and len(tok)>3:
                tokens[no] = tok[1:]
            if tok in ["'","(",")"]:
                tokens.remove(tok)

        # create aspect-polarity dict
        asp_sent_dict = {}
        max_asp_len = 0
        for col in range(len(asp_cols)):
            aspect = df.loc[line,asp_cols[col]]
            if aspect != None:
                asp_sent_dict[aspect] = pol_to_no_shifted(df.loc[line,pol_cols[col]])
                if len(aspect.split()) > max_asp_len:
                    max_asp_len = len(aspect.split())

        label = ""
        # check for one-word-aspects
        for tok in tokens:
            if tok in asp_sent_dict.keys():
                label += tok + " B-ASP -1\n"
            else:
                label += tok + " O -1\n"

        # check for multi-word-aspects
        for ii in range(2,max_asp_len+1):
            for no,tok in enumerate(tokens):
                new_tok = " ".join(tokens[no:no+ii])
                if new_tok not in tokens and new_tok in asp_sent_dict.keys():
                    label = label.replace(tokens[no]+" O -1",tokens[no]+" B-ASP -1")
                    for xx in range(1,ii):
                        label = label.replace(tokens[no+xx]+" O -1",tokens[no+xx]+" I-ASP -1")

        # create duplicates of review in case of more than one aspect
        for key, val in asp_sent_dict.items():
            if key in tokens:
                new_label = label.replace(key+" B-ASP -1", key+" B-ASP "+val)
                data_lines += [new_label]
                data_lines += ["\n"]
            else:
                for ii in range(2,max_asp_len+1):
                    for no,tok in enumerate(tokens):
                        new_tok = " ".join(tokens[no:no+ii])
                        if new_tok == key:
                            new_label = label.replace(tokens[no]+" B-ASP -1",tokens[no]+" B-ASP "+val)
                            for xx in range(1,ii):
                                new_label = new_label.replace(tokens[no+xx]+" I-ASP -1",tokens[no+xx]+" I-ASP "+val)

                            data_lines += [new_label]
                            data_lines += ["\n"]

    return data_lines

# %%
dat_data = dat_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/MAMS/train.dat","w") as f:
    f.write(''.join(dat_data))

# %% [markdown]
# # Create GRACEtxt

# %%
asp_cols = ["aspect_term_"+str(ii) for ii in range(1,aspect_number)]

# %%
import nltk

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('conll2000')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Create chunks and pos tags. Source: https://towardsdatascience.com/chunking-in-nlp-decoded-b4a71b2b4e24

# %%
from nltk.tag import UnigramTagger, BigramTagger
from nltk.chunk import ChunkParserI
from nltk.chunk.util import tree2conlltags, conlltags2tree
from nltk.corpus import conll2000

# %%
def conll_tag_chunks(chunk_sents):
    tagged_sents = [tree2conlltags(tree) for tree in chunk_sents]
    return [[(t, c) for (w, t, c) in sent] for sent in tagged_sents]
    
def combined_tagger(train_data, taggers, backoff=None):
    for tagger in taggers:
        backoff = tagger(train_data, backoff=backoff)
    return backoff

class NGramTagChunker(ChunkParserI):

    def __init__(self,train_sentences,tagger_classes=[UnigramTagger,BigramTagger]):
        train_sent_tags=conll_tag_chunks(train_sentences)
        self.chunk_tagger=combined_tagger(train_sent_tags,tagger_classes)
    
    def parse(self,tagged_sentence):
        if not tagged_sentence:
            return None
        pos_tags=[tag for word, tag in tagged_sentence]
        chunk_pos_tags=self.chunk_tagger.tag(pos_tags)
        chunk_tags=[chunk_tag for (pos_tag,chunk_tag) in chunk_pos_tags]
        wpc_tags=[(word,pos_tag,chunk_tag) for ((word,pos_tag),chunk_tag) in zip(tagged_sentence,chunk_tags)]
        return conlltags2tree(wpc_tags)

# %%
data = conll2000.chunked_sents()
ntc = NGramTagChunker(data)

# %% [markdown]
# Convert tags into BIOES scheme. Source: https://gist.github.com/allanj/5ad206f7f4645c0269b68fb2065712f4

# %%
def iob_iobes(tags):
    """
    IOB2 (BIO) -> IOBES
    """
    new_tags = []
    for i, tag in enumerate(tags):
        if tag == 'O':
            new_tags.append(tag)
        elif tag.split('-')[0] == 'B':
            if i + 1 != len(tags) and \
                    tags[i + 1].split('-')[0] == 'I':
                new_tags.append(tag)
            else:
                new_tags.append(tag.replace('B-', 'S-'))
        elif tag.split('-')[0] == 'I':
            if i + 1 < len(tags) and \
                    tags[i + 1].split('-')[0] == 'I':
                new_tags.append(tag)
            else:
                new_tags.append(tag.replace('I-', 'E-'))
        else:
            raise Exception('Invalid IOB format!')
    return new_tags

# %%
def grace_txt_maker(df):
    
    data_lines = []

    for line in df.index:

        text = df.text[line]
        tokens = nltk.word_tokenize(text)

        # correct tokens
        for no,tok in enumerate(tokens):
            if tok[-1:] == "-" and len(tok)>2:
                tokens[no] = tok[:-1]
            if tok[:1] == "'" and len(tok)>3:
                tokens[no] = tok[1:]
            if tok in ["'","(",")"]:
                tokens.remove(tok)

        # create pos tags
        pos_tags = nltk.pos_tag(tokens)

        # create chunk/phrase tags
        full_tags = tree2conlltags(ntc.parse(pos_tags))
        chunks_list = [full_tags[ii][2] for ii in range(len(full_tags))]
        new_chunks = iob_iobes(chunks_list)

        # create aspect-polarity dict
        asp_sent_dict = {}
        max_asp_len = 0
        for col in range(len(asp_cols)):
            aspect = df.loc[line,asp_cols[col]]
            if aspect != None:
                asp_sent_dict[aspect] = df.loc[line,pol_cols[col]].upper()
                if len(aspect.split()) > max_asp_len:
                    max_asp_len = len(aspect.split())

        label = ""
        # check for one-word-aspects
        for pos,tok in enumerate(tokens):
            label += tok + " " + pos_tags[pos][1] + " " + new_chunks[pos]
            if tok in asp_sent_dict.keys():
                label +=  " B_AP " + asp_sent_dict[tok] + " B_AP+" + asp_sent_dict[tok] + "\n"
            else:
                label += " O O O \n"

        # check for multi-word-aspects
        for ii in range(2,max_asp_len+1):
            for no,tok in enumerate(tokens):
                new_tok = " ".join(tokens[no:no+ii])
                if new_tok not in tokens and new_tok in asp_sent_dict.keys():
                    new_pol = asp_sent_dict[new_tok]
                    label = label.replace(tokens[no]+ " " + pos_tags[no][1] + " " + new_chunks[no] + " O O O \n",
                                          tokens[no]+ " " + pos_tags[no][1] + " " + new_chunks[no] + " B_AP " + \
                                          new_pol + " B_AP+" + new_pol + "\n")
                    for xx in range(1,ii):
                        label = label.replace(tokens[no+xx] + " " + pos_tags[no+xx][1] + " " + new_chunks[no+xx] + " O O O \n",
                                          tokens[no+xx]+ " " + pos_tags[no+xx][1] + " " + new_chunks[no+xx] + " I_AP " + \
                                          new_pol + " I_AP+" + new_pol + "\n")

        data_lines += [label]

    return data_lines

# %%
grace_txt_data = grace_txt_maker(df)

with open("/content/drive/My Drive/Masterarbeit/Data/Final/MAMS/grace_train.txt","w") as f:
    f.write('\n'.join(grace_txt_data))
